# %%
# %%time
from pycolator import *

idCol = 'SpecId'
scoreCol = 'NuXL:score'
excluded = ['SpecId', 'Label', 'ScanNr', 'Peptide', 'Proteins', 'FDR', 'q-val', 'class-specific_q-val', 'Rank', 'temp_score', 'percolator_score']

dSlow = readAndProcess('../data/1-AChernev_080219_dir_HeLa_cyt_UCGA_slow.tsv', idCol, scoreCol, excludedCols = excluded)
features = [x for x in list(dSlow.columns) if (x not in excluded)]
# Out:
# file read...
# strings converted to floats...
# q-values estimated...
# ranks computed...
# features normed...
# floats converted to ints...
# file ready!
# Wall time: 15.3 s

# %%
# %%time

oriIdents = []
oriAUCs = []
dxl = dSlow.loc[dSlow['NuXL:isXL'] == 1]
    
for portion in range(13):
    ix = list(dxl.index)
    newIx = [x for i,x in enumerate(ix) if (i % (pow(2,portion)) == 0)]
    oriAUCs.append(pseudoROC(dxl.loc[newIx], label = '', plot = False))
    oriIdents.append(len(dxl.loc[dxl.index.isin(newIx) & (dxl['q-val'] <= 0.01)]))
# Out:
# 0 [74157, 49701, 69462, 68976, 71820, 75039, 62165, 76627, 69089, 69036, 69581, 69512, 74259, 66562, 71413, 6667, 7524, 7515, 69213, 60688, 66421, 74933, 71923, 79264, 70488, 69713, 76523, 70387, 74374, 11827, 83061, 69838, 12625, 9887, 11704, 79204, 79405, 71286, 81877, 66670, 80177, 78272, 66279, 69678, 68809, 69392, 24777, 69952, 82872, 65879, 75350, 69819, 16087, 81981, 10740, 12628, 75152, 21031, 75789, 11195, 76728, 79506, 80922, 81691, 69977, 78095, 75436, 72039, 81779, 77305, 69171, 82091, 80902, 74188, 62474, 78468, 82005, 62315, 69389, 82002, 16533, 82762, 79069, 82962, 80820, 81535, 83160, 79164, 22984, 70541, 23892, 13855, 80745, 80710, 18680, 11800, 12783, 76829, 78569, 17593, 17151, 75275, 14025, 12730, 10681, 14254, 10820, 79598, 84978, 77197, 77310, 81029, 11209, 75641, 68200, 76952, 75406, 75362, 57000, 76248, 77407, 83069, 74064, 74289, 76283, 72406, 82933, 80435, 75440, 69485, 82648, 46028, 79807, 78165, 75315, 70610, 72296, 76876, 82462, 82777, 66020, 76160, 53204, 70417, 8122, 82679, 81136, 78362, 55803, 79295, 12061, 69393, 70545, 74421, 15425, 78570, 74299, 17296, 84246, 72524, 78634, 65507, 81666, 81334, 78531, 65379, 7842, 12229, 82356, 13890, 84121, 5608, 15606, 75472, 77994, 69346, 75458, 66831, 79233, 83402, 82030, 66693, 75894, 70370, 78985, 79557, 90908, 77590, 77516, 83500, 87242, 73187, 77476, 66851, 74698, 43556, 70507, 81430, 74414, 76716, 66152, 74573, 81913, 11934, 83010, 15623, 83625, 86601, 81005, 15086, 71136, 78635, 13973, 15544, 70288, 11366, 22086, 78532, 21344, 16120, 18831, 69353, 79100, 73991, 91041, 82978, 84030, 76031, 72916, 79590, 74819, 77767, 77693, 81933, 87335, 86608, 79309, 74315, 36593, 82088, 70409, 77582, 63569, 17412, 69224, 78325, 74459, 81722, 81434, 77776, 59418, 77686, 76131, 68983, 75184, 79090, 56533, 75999
, 38168, 56156, 52780, 21210, 79404, 36730, 52714, 9806, 6042, 44255, 73665, 5947, 37833, 54109, 416, 33149, 7209, 31163, 38126, 30580, 3693, 16556, 44908, 53574, 56987, 46388, 72975, 19363, 9997, 37649, 63023, 10264, 51053, 48834, 32854, 15228, 30402, 35113, 21560, 19610, 1116, 10057, 41187, 82783, 1996, 71664, 60549, 33169, 62373, 13425, 37240, 48085, 24744, 12695, 20070, 82224, 28750, 23899, 57388, 12798, 18184, 71071, 81239, 80569, 74303, 19708, 17774, 4927, 25292, 86234, 92281, 7591, 53086, 85928, 10330, 37322, 7580, 14155, 68388, 4132, 34095, 92896, 20944, 48171, 29839, 39396, 51693, 4328, 11880, 14767, 25185, 35151, 71582, 32212, 30333, 26242, 30693, 34066, 23155, 11895, 7531, 5591, 13027, 728, 93134, 33664, 1784, 12396, 25854, 74167, 92884, 4590, 58, 82175, 92508]
# 9 [74157, 89082, 27101, 48112, 69259, 45626, 42518, 39755, 76011, 90901, 84347, 56965, 29881, 21878, 42350, 59993, 48500, 67572, 68320, 72933, 65348, 65182, 29323, 61408, 71643, 67187, 39830, 38015, 61287, 70650, 12846, 50736, 20287, 42061, 27137, 58524, 33292, 47960, 66667, 52466, 4650, 62994, 23622, 23987, 56156, 21210, 36730, 9806, 44255, 5947, 54109, 33149, 31163, 30580, 16556, 53574, 46388, 19363, 37649, 10264, 48834, 15228, 35113, 19610, 10057, 82783, 71664, 33169, 13425, 48085, 12695, 82224, 23899, 12798, 71071, 80569, 19708, 4927, 86234, 7591, 85928, 37322, 14155, 4132, 92896, 48171, 39396, 4328, 14767, 35151, 32212, 26242, 34066, 11895, 5591, 728, 33664, 12396, 74167, 4590, 82175]
# 10 [74157, 27101, 69259, 42518, 76011, 84347, 29881, 42350, 48500, 68320, 65348, 29323, 71643, 39830, 61287, 12846, 20287, 27137, 33292, 66667, 4650, 23622, 56156, 36730, 44255, 54109, 31163, 16556, 46388, 37649, 48834, 35113, 10057, 71664, 13425, 12695, 23899, 71071, 19708, 86234, 85928, 14155, 92896, 39396, 14767, 32212, 34066, 5591, 33664, 74167, 82175]
# 11 [74157, 69259, 76011, 29881, 48500, 65348, 71643, 61287, 20287, 33292, 4650, 56156, 44255, 31163, 46388, 48834, 10057, 13425, 23899, 19708, 85928, 92896, 14767, 34066, 33664, 82175]
# 12 [74157, 76011, 48500, 71643, 20287, 4650, 44255, 46388, 10057, 23899, 85928, 14767, 33664]
# Wall time: 906 ms

# %%
# %%time
import math

aucs = []
idents = []
dxl = dSlow.loc[dSlow['NuXL:isXL'] == 1]

saveName = ''

for portion in range(13):
    print('len / 2^{} => Using {} PSMs:\n'.format(portion, math.floor(len(dxl) / pow(2,portion))))
    dxl = dSlow.loc[dSlow['NuXL:isXL'] == 1]
    
    ix = list(dxl.index)
    newIx = [x for i,x in enumerate(ix) if (i % (math.pow(2,portion)) == 0)]
    
    pxl = percolator_experimental(dxl.loc[newIx], idCol, features, plotSaveName = saveName, plotXLnXL = False)
    
    auct = pseudoROC(pxl, label = '', plot = False)
    aucs.append(auct)
    idents.append(len(pxl.loc[pxl['q-val'] <= 0.01]))
# Out:
# len / 2^0 => Using 51521 PSMs:
#
# Training in iteration 1 with split 1/3 starts!
# Length of positive trainingset: 2992, length of negative training set: 14667
# Optimal parameters are C=10 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 1 with split 2/3 starts!
# Length of positive trainingset: 3189, length of negative training set: 14667
# Optimal parameters are C=10 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 1 with split 3/3 starts!
# Length of positive trainingset: 3679, length of negative training set: 14668
# Optimal parameters are C=10 and class_weight={0: 10, 1: 10}.
#
# Using AUC of pseudo-ROC with x = [0,0.05] as metric.
# Iteration 1/10 done! It yielded an auc of 231.49939476159042.
#
# Training in iteration 2 with split 1/3 starts!
# Length of positive trainingset: 3745, length of negative training set: 14667
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 2 with split 2/3 starts!
# Length of positive trainingset: 3946, length of negative training set: 14667
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 2 with split 3/3 starts!
# Length of positive trainingset: 4207, length of negative training set: 14668
# Optimal parameters are C=10 and class_weight={0: 10, 1: 10}.
#
# Iteration 2/10 done! It yielded an auc of 266.5903697749693.
#
# Training in iteration 3 with split 1/3 starts!
# Length of positive trainingset: 4302, length of negative training set: 14667
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 3 with split 2/3 starts!
# Length of positive trainingset: 4285, length of negative training set: 14667
# Optimal parameters are C=10 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 3 with split 3/3 starts!
# Length of positive trainingset: 4453, length of negative training set: 14668
# Optimal parameters are C=10 and class_weight={0: 10, 1: 10}.
#
# Iteration 3/10 done! It yielded an auc of 279.9568596602827.
#
# Training in iteration 4 with split 1/3 starts!
# Length of positive trainingset: 4479, length of negative training set: 14667
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 4 with split 2/3 starts!
# Length of positive trainingset: 4550, length of negative training set: 14667
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 4 with split 3/3 starts!
# Length of positive trainingset: 4645, length of negative training set: 14668
# Optimal parameters are C=10 and class_weight={0: 10, 1: 10}.
#
# Iteration 4/10 done! It yielded an auc of 285.23247591776493.
#
# Training in iteration 5 with split 1/3 starts!
# Length of positive trainingset: 4583, length of negative training set: 14667
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 5 with split 2/3 starts!
# Length of positive trainingset: 4628, length of negative training set: 14667
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 5 with split 3/3 starts!
# Length of positive trainingset: 4625, length of negative training set: 14668
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 5/10 done! It yielded an auc of 286.73837249133715.
#
# Re-ranking complete. Cutting off low ranks.
#
# Training in iteration 6 with split 1/3 starts!
# Length of positive trainingset: 3914, length of negative training set: 7202
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 6 with split 2/3 starts!
# Length of positive trainingset: 4005, length of negative training set: 7203
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 6 with split 3/3 starts!
# Length of positive trainingset: 4105, length of negative training set: 7203
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 6/10 done! It yielded an auc of 291.7625155963381.
#
# Training in iteration 7 with split 1/3 starts!
# Length of positive trainingset: 4116, length of negative training set: 7202
# Optimal parameters are C=10 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 7 with split 2/3 starts!
# Length of positive trainingset: 4091, length of negative training set: 7203
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 7 with split 3/3 starts!
# Length of positive trainingset: 4118, length of negative training set: 7203
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 7/10 done! It yielded an auc of 292.06783419757016.
#
# Training in iteration 8 with split 1/3 starts!
# Length of positive trainingset: 4141, length of negative training set: 7202
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 8 with split 2/3 starts!
# Length of positive trainingset: 4078, length of negative training set: 7203
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 8 with split 3/3 starts!
# Length of positive trainingset: 4070, length of negative training set: 7203
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 8/10 done! It yielded an auc of 293.3120930625.
#
# Training in iteration 9 with split 1/3 starts!
# Length of positive trainingset: 4111, length of negative training set: 7202
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 9 with split 2/3 starts!
# Length of positive trainingset: 4139, length of negative training set: 7203
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 9 with split 3/3 starts!
# Length of positive trainingset: 4130, length of negative training set: 7203
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 9/10 done! It yielded an auc of 293.9800895181523.
#
# Training in iteration 10 with split 1/3 starts!
# Length of positive trainingset: 4123, length of negative training set: 7202
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 10 with split 2/3 starts!
# Length of positive trainingset: 4124, length of negative training set: 7203
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 10 with split 3/3 starts!
# Length of positive trainingset: 4137, length of negative training set: 7203
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 10/10 done! It yielded an auc of 294.47178105658753.
#
# Terminating and using Iteration 10 with an auc of 294.47.
# len / 2^1 => Using 25760 PSMs:
#
# Training in iteration 1 with split 1/3 starts!
# Length of positive trainingset: 1509, length of negative training set: 7362
# Optimal parameters are C=10 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 1 with split 2/3 starts!
# Length of positive trainingset: 1646, length of negative training set: 7362
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 1 with split 3/3 starts!
# Length of positive trainingset: 1837, length of negative training set: 7362
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Using AUC of pseudo-ROC with x = [0,0.05] as metric.
# Iteration 1/10 done! It yielded an auc of 121.36473877171403.
#
# Training in iteration 2 with split 1/3 starts!
# Length of positive trainingset: 1897, length of negative training set: 7362
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 2 with split 2/3 starts!
# Length of positive trainingset: 1977, length of negative training set: 7362
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 2 with split 3/3 starts!
# Length of positive trainingset: 2068, length of negative training set: 7362
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Iteration 2/10 done! It yielded an auc of 137.98335644518065.
#
# Training in iteration 3 with split 1/3 starts!
# Length of positive trainingset: 2135, length of negative training set: 7362
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 3 with split 2/3 starts!
# Length of positive trainingset: 2141, length of negative training set: 7362
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 3 with split 3/3 starts!
# Length of positive trainingset: 2177, length of negative training set: 7362
# Optimal parameters are C=10 and class_weight={0: 10, 1: 10}.
#
# Iteration 3/10 done! It yielded an auc of 143.38284498145435.
#
# Training in iteration 4 with split 1/3 starts!
# Length of positive trainingset: 2130, length of negative training set: 7362
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 4 with split 2/3 starts!
# Length of positive trainingset: 2236, length of negative training set: 7362
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 4 with split 3/3 starts!
# Length of positive trainingset: 2283, length of negative training set: 7362
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 4/10 done! It yielded an auc of 148.25504902560115.
#
# Training in iteration 5 with split 1/3 starts!
# Length of positive trainingset: 2255, length of negative training set: 7362
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 5 with split 2/3 starts!
# Length of positive trainingset: 2209, length of negative training set: 7362
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 5 with split 3/3 starts!
# Length of positive trainingset: 2323, length of negative training set: 7362
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Iteration 5/10 done! It yielded an auc of 149.4565345984863.
#
# Re-ranking complete. Cutting off low ranks.
#
# Training in iteration 6 with split 1/3 starts!
# Length of positive trainingset: 2127, length of negative training set: 5606
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 6 with split 2/3 starts!
# Length of positive trainingset: 2122, length of negative training set: 5606
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 6 with split 3/3 starts!
# Length of positive trainingset: 2092, length of negative training set: 5606
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 6/10 done! It yielded an auc of 149.9996848598202.
#
# Training in iteration 7 with split 1/3 starts!
# Length of positive trainingset: 2161, length of negative training set: 5606
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 7 with split 2/3 starts!
# Length of positive trainingset: 2091, length of negative training set: 5606
# Optimal parameters are C=10 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 7 with split 3/3 starts!
# Length of positive trainingset: 2175, length of negative training set: 5606
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 7/10 done! It yielded an auc of 151.50662909244167.
#
# Training in iteration 8 with split 1/3 starts!
# Length of positive trainingset: 2150, length of negative training set: 5606
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 8 with split 2/3 starts!
# Length of positive trainingset: 2149, length of negative training set: 5606
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 8 with split 3/3 starts!
# Length of positive trainingset: 2167, length of negative training set: 5606
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Iteration 8/10 done! It yielded an auc of 151.04574658193752.
#
# Training in iteration 9 with split 1/3 starts!
# Length of positive trainingset: 2169, length of negative training set: 5606
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 9 with split 2/3 starts!
# Length of positive trainingset: 2173, length of negative training set: 5606
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 9 with split 3/3 starts!
# Length of positive trainingset: 2148, length of negative training set: 5606
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 9/10 done! It yielded an auc of 151.13158472445298.
#
# Training in iteration 10 with split 1/3 starts!
# Length of positive trainingset: 2133, length of negative training set: 5606
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 10 with split 2/3 starts!
# Length of positive trainingset: 2157, length of negative training set: 5606
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 10 with split 3/3 starts!
# Length of positive trainingset: 2187, length of negative training set: 5606
# Optimal parameters are C=10 and class_weight={0: 10, 1: 10}.
#
# Iteration 10/10 done! It yielded an auc of 151.06377516320094.
#
# Results are not getting better. Terminating and using Iteration 7 with an auc of 151.51.
# len / 2^2 => Using 12880 PSMs:
#
# Training in iteration 1 with split 1/3 starts!
# Length of positive trainingset: 729, length of negative training set: 3712
# Optimal parameters are C=1 and class_weight={0: 30, 1: 10}.
#
# Training in iteration 1 with split 2/3 starts!
# Length of positive trainingset: 853, length of negative training set: 3712
# Optimal parameters are C=1 and class_weight={0: 30, 1: 10}.
#
# Training in iteration 1 with split 3/3 starts!
# Length of positive trainingset: 1004, length of negative training set: 3712
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Using AUC of pseudo-ROC with x = [0,0.05] as metric.
# Iteration 1/10 done! It yielded an auc of 67.2148546685491.
#
# Training in iteration 2 with split 1/3 starts!
# Length of positive trainingset: 1002, length of negative training set: 3712
# Optimal parameters are C=10 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 2 with split 2/3 starts!
# Length of positive trainingset: 1062, length of negative training set: 3712
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 2 with split 3/3 starts!
# Length of positive trainingset: 1115, length of negative training set: 3712
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 2/10 done! It yielded an auc of 74.4458270882999.
#
# Training in iteration 3 with split 1/3 starts!
# Length of positive trainingset: 1105, length of negative training set: 3712
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 3 with split 2/3 starts!
# Length of positive trainingset: 1133, length of negative training set: 3712
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 3 with split 3/3 starts!
# Length of positive trainingset: 1134, length of negative training set: 3712
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 3/10 done! It yielded an auc of 76.3773637344454.
#
# Training in iteration 4 with split 1/3 starts!
# Length of positive trainingset: 1122, length of negative training set: 3712
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 4 with split 2/3 starts!
# Length of positive trainingset: 1128, length of negative training set: 3712
# Optimal parameters are C=10 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 4 with split 3/3 starts!
# Length of positive trainingset: 1111, length of negative training set: 3712
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 4/10 done! It yielded an auc of 77.00611932128895.
#
# Re-ranking complete. Cutting off low ranks.
#
# Training in iteration 5 with split 1/3 starts!
# Length of positive trainingset: 1103, length of negative training set: 3268
# Optimal parameters are C=10 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 5 with split 2/3 starts!
# Length of positive trainingset: 1062, length of negative training set: 3269
# Optimal parameters are C=10 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 5 with split 3/3 starts!
# Length of positive trainingset: 1068, length of negative training set: 3269
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 5/10 done! It yielded an auc of 77.99527859845213.
#
# Training in iteration 6 with split 1/3 starts!
# Length of positive trainingset: 1101, length of negative training set: 3268
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 6 with split 2/3 starts!
# Length of positive trainingset: 1121, length of negative training set: 3269
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 6 with split 3/3 starts!
# Length of positive trainingset: 1098, length of negative training set: 3269
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Iteration 6/10 done! It yielded an auc of 77.55112413364807.
#
# Training in iteration 7 with split 1/3 starts!
# Length of positive trainingset: 1091, length of negative training set: 3268
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 7 with split 2/3 starts!
# Length of positive trainingset: 1091, length of negative training set: 3269
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 7 with split 3/3 starts!
# Length of positive trainingset: 1137, length of negative training set: 3269
# Optimal parameters are C=10 and class_weight={0: 10, 1: 10}.
#
# Iteration 7/10 done! It yielded an auc of 77.97017693801466.
#
# Training in iteration 8 with split 1/3 starts!
# Length of positive trainingset: 1131, length of negative training set: 3268
# Optimal parameters are C=10 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 8 with split 2/3 starts!
# Length of positive trainingset: 1105, length of negative training set: 3269
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 8 with split 3/3 starts!
# Length of positive trainingset: 1101, length of negative training set: 3269
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 8/10 done! It yielded an auc of 77.7793403311637.
#
# Results are not getting better. Terminating and using Iteration 5 with an auc of 78.0.
# len / 2^3 => Using 6440 PSMs:
#
# Training in iteration 1 with split 1/3 starts!
# Length of positive trainingset: 371, length of negative training set: 1882
# Optimal parameters are C=1 and class_weight={0: 30, 1: 10}.
#
# Training in iteration 1 with split 2/3 starts!
# Length of positive trainingset: 459, length of negative training set: 1882
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 1 with split 3/3 starts!
# Length of positive trainingset: 522, length of negative training set: 1882
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Using AUC of pseudo-ROC with x = [0,0.05] as metric.
# Iteration 1/10 done! It yielded an auc of 35.39890020167383.
#
# Training in iteration 2 with split 1/3 starts!
# Length of positive trainingset: 539, length of negative training set: 1882
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 2 with split 2/3 starts!
# Length of positive trainingset: 530, length of negative training set: 1882
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 2 with split 3/3 starts!
# Length of positive trainingset: 581, length of negative training set: 1882
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Iteration 2/10 done! It yielded an auc of 37.0917467554123.
#
# Training in iteration 3 with split 1/3 starts!
# Length of positive trainingset: 547, length of negative training set: 1882
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 3 with split 2/3 starts!
# Length of positive trainingset: 575, length of negative training set: 1882
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 3 with split 3/3 starts!
# Length of positive trainingset: 570, length of negative training set: 1882
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 3/10 done! It yielded an auc of 39.57610726112765.
#
# Training in iteration 4 with split 1/3 starts!
# Length of positive trainingset: 572, length of negative training set: 1882
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 4 with split 2/3 starts!
# Length of positive trainingset: 569, length of negative training set: 1882
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 4 with split 3/3 starts!
# Length of positive trainingset: 593, length of negative training set: 1882
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Iteration 4/10 done! It yielded an auc of 39.15078835745406.
#
# Re-ranking complete. Cutting off low ranks.
#
# Training in iteration 5 with split 1/3 starts!
# Length of positive trainingset: 576, length of negative training set: 1760
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 5 with split 2/3 starts!
# Length of positive trainingset: 573, length of negative training set: 1761
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 5 with split 3/3 starts!
# Length of positive trainingset: 561, length of negative training set: 1761
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Iteration 5/10 done! It yielded an auc of 40.36006335531145.
#
# Training in iteration 6 with split 1/3 starts!
# Length of positive trainingset: 565, length of negative training set: 1760
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 6 with split 2/3 starts!
# Length of positive trainingset: 586, length of negative training set: 1761
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 6 with split 3/3 starts!
# Length of positive trainingset: 559, length of negative training set: 1761
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 6/10 done! It yielded an auc of 40.59168867451942.
#
# Training in iteration 7 with split 1/3 starts!
# Length of positive trainingset: 575, length of negative training set: 1760
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 7 with split 2/3 starts!
# Length of positive trainingset: 573, length of negative training set: 1761
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 7 with split 3/3 starts!
# Length of positive trainingset: 580, length of negative training set: 1761
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Iteration 7/10 done! It yielded an auc of 40.56926505635192.
#
# Training in iteration 8 with split 1/3 starts!
# Length of positive trainingset: 564, length of negative training set: 1760
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 8 with split 2/3 starts!
# Length of positive trainingset: 572, length of negative training set: 1761
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 8 with split 3/3 starts!
# Length of positive trainingset: 573, length of negative training set: 1761
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 8/10 done! It yielded an auc of 40.92725314841953.
#
# Training in iteration 9 with split 1/3 starts!
# Length of positive trainingset: 571, length of negative training set: 1760
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 9 with split 2/3 starts!
# Length of positive trainingset: 569, length of negative training set: 1761
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 9 with split 3/3 starts!
# Length of positive trainingset: 586, length of negative training set: 1761
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 9/10 done! It yielded an auc of 40.521103194796275.
#
# Training in iteration 10 with split 1/3 starts!
# Length of positive trainingset: 586, length of negative training set: 1760
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 10 with split 2/3 starts!
# Length of positive trainingset: 559, length of negative training set: 1761
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 10 with split 3/3 starts!
# Length of positive trainingset: 569, length of negative training set: 1761
# Optimal parameters are C=10 and class_weight={0: 10, 1: 10}.
#
# Iteration 10/10 done! It yielded an auc of 40.87575412052389.
#
# Terminating and using Iteration 8 with an auc of 40.93.
# len / 2^4 => Using 3220 PSMs:
#
# Training in iteration 1 with split 1/3 starts!
# Length of positive trainingset: 187, length of negative training set: 929
# Optimal parameters are C=1 and class_weight={0: 30, 1: 10}.
#
# Training in iteration 1 with split 2/3 starts!
# Length of positive trainingset: 222, length of negative training set: 929
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 1 with split 3/3 starts!
# Length of positive trainingset: 261, length of negative training set: 930
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Using AUC of pseudo-ROC with x = [0,0.05] as metric.
# Iteration 1/10 done! It yielded an auc of 16.413633811018403.
#
# Training in iteration 2 with split 1/3 starts!
# Length of positive trainingset: 259, length of negative training set: 929
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 2 with split 2/3 starts!
# Length of positive trainingset: 243, length of negative training set: 929
# Optimal parameters are C=10 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 2 with split 3/3 starts!
# Length of positive trainingset: 279, length of negative training set: 930
# Optimal parameters are C=10 and class_weight={0: 30, 1: 10}.
#
# Iteration 2/10 done! It yielded an auc of 19.34860765264095.
#
# Training in iteration 3 with split 1/3 starts!
# Length of positive trainingset: 294, length of negative training set: 929
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 3 with split 2/3 starts!
# Length of positive trainingset: 289, length of negative training set: 929
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 3 with split 3/3 starts!
# Length of positive trainingset: 268, length of negative training set: 930
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Iteration 3/10 done! It yielded an auc of 19.473605726956926.
#
# Re-ranking complete. Cutting off low ranks.
#
# Training in iteration 4 with split 1/3 starts!
# Length of positive trainingset: 270, length of negative training set: 898
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 4 with split 2/3 starts!
# Length of positive trainingset: 275, length of negative training set: 899
# Optimal parameters are C=1 and class_weight={0: 30, 1: 10}.
#
# Training in iteration 4 with split 3/3 starts!
# Length of positive trainingset: 281, length of negative training set: 899
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Iteration 4/10 done! It yielded an auc of 19.515344990819433.
#
# Training in iteration 5 with split 1/3 starts!
# Length of positive trainingset: 281, length of negative training set: 898
# Optimal parameters are C=10 and class_weight={0: 30, 1: 10}.
#
# Training in iteration 5 with split 2/3 starts!
# Length of positive trainingset: 290, length of negative training set: 899
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 5 with split 3/3 starts!
# Length of positive trainingset: 274, length of negative training set: 899
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Iteration 5/10 done! It yielded an auc of 19.64067624184221.
#
# Training in iteration 6 with split 1/3 starts!
# Length of positive trainingset: 286, length of negative training set: 898
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 6 with split 2/3 starts!
# Length of positive trainingset: 268, length of negative training set: 899
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 6 with split 3/3 starts!
# Length of positive trainingset: 297, length of negative training set: 899
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Iteration 6/10 done! It yielded an auc of 19.202417146070733.
#
# Training in iteration 7 with split 1/3 starts!
# Length of positive trainingset: 285, length of negative training set: 898
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 7 with split 2/3 starts!
# Length of positive trainingset: 294, length of negative training set: 899
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 7 with split 3/3 starts!
# Length of positive trainingset: 294, length of negative training set: 899
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 7/10 done! It yielded an auc of 19.624853159705044.
#
# Training in iteration 8 with split 1/3 starts!
# Length of positive trainingset: 291, length of negative training set: 898
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 8 with split 2/3 starts!
# Length of positive trainingset: 297, length of negative training set: 899
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 8 with split 3/3 starts!
# Length of positive trainingset: 281, length of negative training set: 899
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 8/10 done! It yielded an auc of 19.894716942138952.
#
# Training in iteration 9 with split 1/3 starts!
# Length of positive trainingset: 286, length of negative training set: 898
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 9 with split 2/3 starts!
# Length of positive trainingset: 294, length of negative training set: 899
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 9 with split 3/3 starts!
# Length of positive trainingset: 305, length of negative training set: 899
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Iteration 9/10 done! It yielded an auc of 19.352464610067187.
#
# Training in iteration 10 with split 1/3 starts!
# Length of positive trainingset: 287, length of negative training set: 898
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 10 with split 2/3 starts!
# Length of positive trainingset: 283, length of negative training set: 899
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 10 with split 3/3 starts!
# Length of positive trainingset: 291, length of negative training set: 899
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Iteration 10/10 done! It yielded an auc of 17.95760775021386.
#
# Terminating and using Iteration 8 with an auc of 19.89.
# len / 2^5 => Using 1610 PSMs:
#
# Training in iteration 1 with split 1/3 starts!
# Length of positive trainingset: 90, length of negative training set: 464
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 1 with split 2/3 starts!
# Length of positive trainingset: 113, length of negative training set: 465
# Optimal parameters are C=0.1 and class_weight={0: 30, 1: 10}.
#
# Training in iteration 1 with split 3/3 starts!
# Length of positive trainingset: 131, length of negative training set: 465
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Using AUC of pseudo-ROC with x = [0,0.05] as metric.
# Iteration 1/10 done! It yielded an auc of 9.059742502142083.
#
# Training in iteration 2 with split 1/3 starts!
# Length of positive trainingset: 124, length of negative training set: 464
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 2 with split 2/3 starts!
# Length of positive trainingset: 146, length of negative training set: 465
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 2 with split 3/3 starts!
# Length of positive trainingset: 165, length of negative training set: 465
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Iteration 2/10 done! It yielded an auc of 9.826633883312205.
#
# Training in iteration 3 with split 1/3 starts!
# Length of positive trainingset: 146, length of negative training set: 464
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 3 with split 2/3 starts!
# Length of positive trainingset: 151, length of negative training set: 465
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 3 with split 3/3 starts!
# Length of positive trainingset: 171, length of negative training set: 465
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Iteration 3/10 done! It yielded an auc of 10.560185421202645.
#
# Training in iteration 4 with split 1/3 starts!
# Length of positive trainingset: 150, length of negative training set: 464
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 4 with split 2/3 starts!
# Length of positive trainingset: 166, length of negative training set: 465
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 4 with split 3/3 starts!
# Length of positive trainingset: 162, length of negative training set: 465
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Iteration 4/10 done! It yielded an auc of 10.362359310558904.
#
# Re-ranking complete. Cutting off low ranks.
#
# Training in iteration 5 with split 1/3 starts!
# Length of positive trainingset: 139, length of negative training set: 458
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 5 with split 2/3 starts!
# Length of positive trainingset: 151, length of negative training set: 458
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 5 with split 3/3 starts!
# Length of positive trainingset: 145, length of negative training set: 458
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Iteration 5/10 done! It yielded an auc of 9.46657718536946.
#
# Training in iteration 6 with split 1/3 starts!
# Length of positive trainingset: 154, length of negative training set: 458
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 6 with split 2/3 starts!
# Length of positive trainingset: 140, length of negative training set: 458
# Optimal parameters are C=1 and class_weight={0: 30, 1: 10}.
#
# Training in iteration 6 with split 3/3 starts!
# Length of positive trainingset: 140, length of negative training set: 458
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Iteration 6/10 done! It yielded an auc of 9.735013268352848.
#
# Results are not getting better. Terminating and using Iteration 3 with an auc of 10.56.
# len / 2^6 => Using 805 PSMs:
#
# Training in iteration 1 with split 1/3 starts!
# Length of positive trainingset: 47, length of negative training set: 230
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 1 with split 2/3 starts!
# Length of positive trainingset: 61, length of negative training set: 231
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 1 with split 3/3 starts!
# Length of positive trainingset: 49, length of negative training set: 231
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Using AUC of pseudo-ROC with x = [0,0.05] as metric.
# Iteration 1/10 done! It yielded an auc of 3.383965649886676.
#
# Training in iteration 2 with split 1/3 starts!
# Length of positive trainingset: 63, length of negative training set: 230
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 2 with split 2/3 starts!
# Length of positive trainingset: 63, length of negative training set: 231
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 2 with split 3/3 starts!
# Length of positive trainingset: 62, length of negative training set: 231
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Iteration 2/10 done! It yielded an auc of 4.392890984426911.
#
# Training in iteration 3 with split 1/3 starts!
# Length of positive trainingset: 69, length of negative training set: 230
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 3 with split 2/3 starts!
# Length of positive trainingset: 68, length of negative training set: 231
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 3 with split 3/3 starts!
# Length of positive trainingset: 59, length of negative training set: 231
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Iteration 3/10 done! It yielded an auc of 4.078246276645045.
#
# Re-ranking complete. Cutting off low ranks.
#
# Training in iteration 4 with split 1/3 starts!
# Length of positive trainingset: 74, length of negative training set: 228
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 4 with split 2/3 starts!
# Length of positive trainingset: 65, length of negative training set: 228
# Optimal parameters are C=10 and class_weight={0: 30, 1: 10}.
#
# Training in iteration 4 with split 3/3 starts!
# Length of positive trainingset: 69, length of negative training set: 228
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Iteration 4/10 done! It yielded an auc of 4.062606309071942.
#
# Training in iteration 5 with split 1/3 starts!
# Length of positive trainingset: 64, length of negative training set: 228
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 5 with split 2/3 starts!
# Length of positive trainingset: 70, length of negative training set: 228
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 5 with split 3/3 starts!
# Length of positive trainingset: 75, length of negative training set: 228
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Iteration 5/10 done! It yielded an auc of 3.979204072637926.
#
# Results are not getting better. Terminating and using Iteration 2 with an auc of 4.39.
# len / 2^7 => Using 402 PSMs:
#
# Training in iteration 1 with split 1/3 starts!
# Length of positive trainingset: 16, length of negative training set: 113
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 1 with split 2/3 starts!
# Length of positive trainingset: 28, length of negative training set: 113
# Optimal parameters are C=0.1 and class_weight={0: 30, 1: 10}.
#
# Training in iteration 1 with split 3/3 starts!
# Length of positive trainingset: 35, length of negative training set: 114
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Using AUC of pseudo-ROC with x = [0,0.05] as metric.
# Iteration 1/10 done! It yielded an auc of 1.9144310823311725.
#
# Training in iteration 2 with split 1/3 starts!
# Length of positive trainingset: 28, length of negative training set: 113
# Optimal parameters are C=10 and class_weight={0: 30, 1: 10}.
#
# Training in iteration 2 with split 2/3 starts!
# Length of positive trainingset: 31, length of negative training set: 113
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 2 with split 3/3 starts!
# Length of positive trainingset: 31, length of negative training set: 114
# Optimal parameters are C=1 and class_weight={0: 30, 1: 10}.
#
# Iteration 2/10 done! It yielded an auc of 1.830615942028984.
#
# Re-ranking complete. Cutting off low ranks.
#
# Training in iteration 3 with split 1/3 starts!
# Length of positive trainingset: 32, length of negative training set: 113
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 3 with split 2/3 starts!
# Length of positive trainingset: 26, length of negative training set: 113
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 3 with split 3/3 starts!
# Length of positive trainingset: 37, length of negative training set: 114
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Iteration 3/10 done! It yielded an auc of 1.885703918722786.
#
# Training in iteration 4 with split 1/3 starts!
# Length of positive trainingset: 40, length of negative training set: 113
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 4 with split 2/3 starts!
# Length of positive trainingset: 31, length of negative training set: 113
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 4 with split 3/3 starts!
# Length of positive trainingset: 32, length of negative training set: 114
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Iteration 4/10 done! It yielded an auc of 1.8479245283018864.
#
# Results are not getting better. Terminating and using Iteration 1 with an auc of 1.91.
# len / 2^8 => Using 201 PSMs:
#
# Training in iteration 1 with split 1/3 starts!
# Length of positive trainingset: 15, length of negative training set: 52
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 1 with split 2/3 starts!
# Length of positive trainingset: 14, length of negative training set: 53
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 1 with split 3/3 starts!
# Length of positive trainingset: 22, length of negative training set: 53
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Using AUC of pseudo-ROC with x = [0,0.05] as metric.
# Iteration 1/10 done! It yielded an auc of 0.9516129032258056.
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Training in iteration 2 with split 1/3 starts!
# Length of positive trainingset: 19, length of negative training set: 52
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 2 with split 2/3 starts!
# Length of positive trainingset: 20, length of negative training set: 53
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 2 with split 3/3 starts!
# Length of positive trainingset: 15, length of negative training set: 53
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Iteration 2/10 done! It yielded an auc of 0.9423076923076916.
#
# Re-ranking complete. Cutting off low ranks.
#
# Training in iteration 3 with split 1/3 starts!
# Length of positive trainingset: 14, length of negative training set: 52
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 3 with split 2/3 starts!
# Length of positive trainingset: 19, length of negative training set: 53
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 3 with split 3/3 starts!
# Length of positive trainingset: 17, length of negative training set: 53
# Optimal parameters are C=0.1 and class_weight={0: 30, 1: 10}.
#
# Iteration 3/10 done! It yielded an auc of 0.9400000000000008.
#
# Training in iteration 4 with split 1/3 starts!
# Length of positive trainingset: 18, length of negative training set: 52
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Optimal parameters are C=0.1 and class_weight={0: 30, 1: 10}.
#
# Training in iteration 4 with split 2/3 starts!
# Length of positive trainingset: 19, length of negative training set: 53
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 4 with split 3/3 starts!
# Length of positive trainingset: 15, length of negative training set: 53
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Iteration 4/10 done! It yielded an auc of 0.9444444444444458.
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Results are not getting better. Terminating and using Iteration 1 with an auc of 0.95.
# len / 2^9 => Using 100 PSMs:
#
# Training in iteration 1 with split 1/3 starts!
# Length of positive trainingset: 5, length of negative training set: 26
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 1 with split 2/3 starts!
# Length of positive trainingset: 7, length of negative training set: 26
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 1 with split 3/3 starts!
# Length of positive trainingset: 8, length of negative training set: 26
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Using identifications at 1% q-value with rank 1 as metric.
# Iteration 1/10 done! It yielded identifications of 12.
#
# Training in iteration 2 with split 1/3 starts!
# Length of positive trainingset: 9, length of negative training set: 26
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 2 with split 2/3 starts!
# Length of positive trainingset: 7, length of negative training set: 26
# Optimal parameters are C=10 and class_weight={0: 30, 1: 10}.
#
# Training in iteration 2 with split 3/3 starts!
# Length of positive trainingset: 7, length of negative training set: 26
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Iteration 2/10 done! It yielded identifications of 12.
#
# Re-ranking complete. Cutting off low ranks.
#
# Training in iteration 3 with split 1/3 starts!
# Length of positive trainingset: 8, length of negative training set: 26
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 3 with split 2/3 starts!
# Length of positive trainingset: 6, length of negative training set: 26
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 3 with split 3/3 starts!
# Length of positive trainingset: 8, length of negative training set: 26
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Iteration 3/10 done! It yielded identifications of 10.
#
# Training in iteration 4 with split 1/3 starts!
# Length of positive trainingset: 6, length of negative training set: 26
# Optimal parameters are C=0.1 and class_weight={0: 30, 1: 10}.
#
# Training in iteration 4 with split 2/3 starts!
# Length of positive trainingset: 6, length of negative training set: 26
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 4 with split 3/3 starts!
# Length of positive trainingset: 9, length of negative training set: 26
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Iteration 4/10 done! It yielded identifications of 12.
#
# Results are not getting better. Terminating and using Iteration 1 with identifications of 12.
# len / 2^10 => Using 50 PSMs:
#
# Training in iteration 1 with split 1/3 starts!
# Length of positive trainingset: 3, length of negative training set: 13
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 1 with split 2/3 starts!
# Length of positive trainingset: 4, length of negative training set: 13
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 1 with split 3/3 starts!
# Length of positive trainingset: 8, length of negative training set: 14
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Using identifications at 1% q-value with rank 1 as metric.
# Iteration 1/10 done! It yielded identifications of 10.
#
# Training in iteration 2 with split 1/3 starts!
# Length of positive trainingset: 8, length of negative training set: 13
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 2 with split 2/3 starts!
# Length of positive trainingset: 9, length of negative training set: 13
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 2 with split 3/3 starts!
# Length of positive trainingset: 9, length of negative training set: 14
# Optimal parameters are C=0.1 and class_weight={0: 30, 1: 10}.
#
# Iteration 2/10 done! It yielded identifications of 13.
#
# Training in iteration 3 with split 1/3 starts!
# Length of positive trainingset: 9, length of negative training set: 13
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 3 with split 2/3 starts!
# Length of positive trainingset: 6, length of negative training set: 13
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 3 with split 3/3 starts!
# Length of positive trainingset: 6, length of negative training set: 14
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Iteration 3/10 done! It yielded identifications of 9.
#
# Re-ranking complete. Cutting off low ranks.
#
# Training in iteration 4 with split 1/3 starts!
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Length of positive trainingset: 4, length of negative training set: 13
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 4 with split 2/3 starts!
# Length of positive trainingset: 7, length of negative training set: 13
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 4 with split 3/3 starts!
# Length of positive trainingset: 6, length of negative training set: 14
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <timed exec> in <module>
#
# ~\Documents\Uni\Bachelorarbeit\Bachelor-Thesis\src\pycolator.py in percolator_experimental(df, idColName, features, I, qTrain, centralScoringQ, useRankOneOnly, plotEveryIter, plotXLnXL, suppressLog, plotSaveName, plotDPI, termWorseIters, cutOffImprove, rankOption, scanNrTest, peptideTest, lowRankDecoy, KFoldTest, balancedOption, fastCV, propTarDec, propXLnXL, balancingInner, balancingOuter, optimalRanking, specialGrid, identsAsMetric)
#     131             # merge: calculate comparable score
#     132             calcQ(validate, scoreNameTemp, addXlQ = False)
# --> 133             qThreshold = min(validate.loc[validate['q-val'] <= centralScoringQ, scoreNameTemp])
#     134             decoyMedian = np.median(validate.loc[validate.Label == 0, scoreNameTemp])
#     135             validate[scoreName] = (validate[scoreNameTemp] - qThreshold) / (qThreshold - decoyMedian)
#
# ValueError: min() arg is an empty sequence

# %%
rangeOfi = 10
x = [len(dxl)/(math.pow(2,i)) for i in range(rangeOfi)]

ratioAUCs = [p / o if (o!=0) else p + 1 for p,o in zip(aucs,oriAUCs)]
ratioIdents = [p / o for p,o in zip(idents,oriIdents)]
plt.xscale('log')
plt.ylim(0,2.5)
#plt.yscale('log')
print(ratioAUCs)
print(ratioIdents)
plt.plot(x,ratioAUCs)
plt.show()
plt.ylim(0,2.5)
plt.xscale('log')
plt.plot(x,ratioIdents)
# Out:
# [1.6242214634260073, 1.7452896058397962, 1.786964586826641, 1.8121813715976547, 1.7087329594393441, 2.0081034551578307, 1.6577306093866764, 2.192336614711512, 1.021243115656963, 1.0]
# [1.7447685478757133, 1.7805960684844642, 1.837769328263625, 1.9088607594936708, 1.8282828282828283, 1.9393939393939394, 1.78, 1.8, 2.230769230769231, 1.7142857142857142]

# %%
oriAUCs
# Out:
# [181.32015414316143,
#  86.8725338896442,
#  43.68192266633846,
#  22.616052812258456,
#  11.167249086475055,
#  5.36195071338696,
#  2.6461283537554703,
#  0.8548387096774186,
#  0.931818181818181,
#  0.0,
#  0.0,
#  0.0,
#  0.0]

# %%
aucs
# Out:
# [294.5040861110349,
#  151.61773043056147,
#  78.05804888924679,
#  40.984389605443525,
#  19.081846580328833,
#  10.767351753938351,
#  4.3865679683864185,
#  1.874094202898549,
#  0.9516129032258056,
#  0.0]

# %%
# AUCS of percolator
plt.xscale('log')
plt.yscale('log')

plt.plot([len(dxl)/(math.pow(2,i)) for i in range(rangeOfi)], aucs)
plt.title('AUC of XLs in dSlow using optimal ranking over number of PSMs in dataset')
plt.savefig('../results/ratioTests/optimalRanking_idents.png')

# %%
# Idents of percolator
plt.xscale('log')
plt.yscale('log')

plt.plot([len(dxl)/(math.pow(2,i)) for i in range(rangeOfi)], idents)
plt.title('Idents (1% FDR) of dSlow[XL] over num of PSMs in dataset')
plt.savefig('../results/ratioTests/optimalRanking_idents.png')

# %%
# ratio of idents in df of percolator
plt.xscale('log')
plt.plot([len(dxl)/(math.pow(2,i)) for i in range(rangeOfi)],[idents[i]/(len(dxl)/(math.pow(2,i))) for i in range(rangeOfi)])

# %%
# ratio of idents in df of NuXL
plt.xscale('log')
plt.plot([len(dSlow)/(math.pow(2,i)) for i in range(rangeOfi)],[oriIdents[i]/(len(dSlow)/(math.pow(2,i))) for i in range(rangeOfi)])
