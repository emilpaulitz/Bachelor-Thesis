# %%
# %%time
from pycolator import *

idCol = 'SpecId'
scoreCol = 'NuXL:score'
excluded = ['SpecId', 'Label', 'ScanNr', 'Peptide', 'Proteins', 'FDR', 'q-val', 'class-specific_q-val', 'Rank', 'temp_score', 'percolator_score']

dSlow = readAndProcess('../data/1-AChernev_080219_dir_HeLa_cyt_UCGA_slow.tsv', idCol, scoreCol, excludedCols = excluded)
features = [x for x in list(dSlow.columns) if (x not in excluded)]
# Out:
# file read...
# strings converted to floats...
# q-values estimated...
# ranks computed...
# features normed...
# floats converted to ints...
# file ready!
# Wall time: 14.5 s

# %% [markdown]
# # TODO: MONTE CARLO SAMPLING INTO BOX PLOTS?

# %%
# set up metrices of original data set

oriIdents = []
oriExpectIdents = []
oriLen = []
oriAUCs = []
dxl = dSlow.loc[dSlow['NuXL:isXL'] == 1]
    
for portion in range(12): # smallest df has 3 entries
    ix = list(dxl.index)
    newDf = dxl.loc[dxl['q-val'] <= 0.1].sample(frac = 1/pow(2,portion))
    oriExpectIdents.append(len(newDf.loc[newDf['q-val'] <= 0.01]))
    newDf = calcQ(newDf, 'NuXL:score')
    newIx = newDf.index
    #newIx = [x for i,x in enumerate(ix) if (i % (pow(2,portion)) == 0)]
    try:
        oriAUCs.append(pseudoROC(newDf, plot = False))
    except:
        oriAUCs.append(0.0)
    oriLen.append(len(newDf))
    oriIdents.append(len(newDf.loc[newDf['q-val'] <= 0.01]))

# %%
fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8])
ax.set_ylim(0,1.1)
x = range(12)
y = [e/l for e,l in zip(oriExpectIdents,oriLen)]
ax.plot(x, y)
ax.set_xlabel('size of dataset')
ax.set_title('portion of dataset with an expected q-value of less than 1%')
ax.set_xticks(x)
ax.set_xticklabels(oriLen)
plt.show()
# Out:
# [Text(0, 0, '6101'),
#  Text(0, 0, '3050'),
#  Text(0, 0, '1525'),
#  Text(0, 0, '763'),
#  Text(0, 0, '381'),
#  Text(0, 0, '191'),
#  Text(0, 0, '95'),
#  Text(0, 0, '48'),
#  Text(0, 0, '24'),
#  Text(0, 0, '12'),
#  Text(0, 0, '6'),
#  Text(0, 0, '3')]

# %%
fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8])
x = range(12)
y = [i/e if (e != 0) else np.nan for i,e in zip(oriIdents, oriExpectIdents)]
yUpper = max(2 - min(y), max(y)) + 0.1
ax.set_ylim(2 - yUpper, yUpper)
ax.plot(x, y)
ax.set_xlabel('size of dataset')
ax.set_title('number of found / number of expected idents at 1% q-value')
ax.set_xticks(x)
ax.set_xticklabels(oriLen)
plt.show()
# Out:
# [Text(0, 0, '6101'),
#  Text(0, 0, '3050'),
#  Text(0, 0, '1525'),
#  Text(0, 0, '763'),
#  Text(0, 0, '381'),
#  Text(0, 0, '191'),
#  Text(0, 0, '95'),
#  Text(0, 0, '48'),
#  Text(0, 0, '24'),
#  Text(0, 0, '12'),
#  Text(0, 0, '6'),
#  Text(0, 0, '3')]

# %%
# calculate metrices of percolator results

# expected idents if algorithm would work as well as NuXL:score
expId = []

# expected idents if the algorithm would work as well as with the whole data set
pExpectIdents = []

pIdents = []
pLen = []
pAUCs = []

saveName = ''

iters = 12 # smallest df has 3 entries
for portion in range(iters):
    dxl = dSlow.loc[dSlow['NuXL:isXL'] == 1]
    
    ix = list(dxl.index)
    newDf = dxl.loc[dxl['q-val'] <= 0.1].sample(frac = 1/pow(2,portion))
    expId.append(len(newDf.loc[newDf['q-val'] <= 0.01]))
    newIx = newDf.index
    
    try:
        pxl = percolator_experimental(newDf, idCol, features, plotSaveName = saveName, plotXLnXL = False)
    except:
        print('Dataset too small: {} PSMs. Quitting evaluation.'.format(len(newDf)))
        iters = portion
        del expId[-1]
        break
        
    if (portion == 0):
        fullP = pd.DataFrame(pxl.loc[:,['Label', 'percolator_score', 'q-val']])
        
    # maybe calc Q with sampled subset of fullP?
    pExpectIdents.append(len(fullP.loc[(fullP.index.isin(newIx)) & (fullP['q-val'] <= 0.01)]))
    
    try:
        pAUCs.append(pseudoROC(newDf, plot = False))
    except:
        print('Error while calculating AUC in iteration {}/{}!'.format(portion + 1, iters))
        pAUCs.append(0.0)
    pLen.append(len(pxl))
    pIdents.append(len(pxl.loc[pxl['q-val'] <= 0.01]))
# Out:
# Training in iteration 1 with split 1/3 starts!
# Length of positive trainingset: 3001, length of negative training set: 432
# Optimal parameters are C=10 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 1 with split 2/3 starts!
# Length of positive trainingset: 3152, length of negative training set: 433
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 1 with split 3/3 starts!
# Length of positive trainingset: 3331, length of negative training set: 433
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Using AUC of pseudo-ROC with x = [0,0.05] as metric.
# Iteration 1/10 done! It yielded an auc of 216.3823224606507.
#
# Training in iteration 2 with split 1/3 starts!
# Length of positive trainingset: 3351, length of negative training set: 432
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 2 with split 2/3 starts!
# Length of positive trainingset: 3380, length of negative training set: 433
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 2 with split 3/3 starts!
# Length of positive trainingset: 3376, length of negative training set: 433
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Iteration 2/10 done! It yielded an auc of 217.80834854289975.
#
# Re-ranking complete. Cutting off low ranks.
#
# Training in iteration 3 with split 1/3 starts!
# Length of positive trainingset: 2902, length of negative training set: 240
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 3 with split 2/3 starts!
# Length of positive trainingset: 2918, length of negative training set: 240
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 3 with split 3/3 starts!
# Length of positive trainingset: 2958, length of negative training set: 240
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Iteration 3/10 done! It yielded an auc of 217.61521851151969.
#
# Training in iteration 4 with split 1/3 starts!
# Length of positive trainingset: 2950, length of negative training set: 240
# Optimal parameters are C=10 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 4 with split 2/3 starts!
# Length of positive trainingset: 2955, length of negative training set: 240
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 4 with split 3/3 starts!
# Length of positive trainingset: 2944, length of negative training set: 240
# Optimal parameters are C=10 and class_weight={0: 10, 1: 10}.
#
# Iteration 4/10 done! It yielded an auc of 217.47428219725188.
#
# Training in iteration 5 with split 1/3 starts!
# Length of positive trainingset: 2941, length of negative training set: 240
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 5 with split 2/3 starts!
# Length of positive trainingset: 2967, length of negative training set: 240
# Optimal parameters are C=10 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 5 with split 3/3 starts!
# Length of positive trainingset: 2960, length of negative training set: 240
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Iteration 5/10 done! It yielded an auc of 218.21747237659008.
#
# Training in iteration 6 with split 1/3 starts!
# Length of positive trainingset: 2956, length of negative training set: 240
# Optimal parameters are C=10 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 6 with split 2/3 starts!
# Length of positive trainingset: 2952, length of negative training set: 240
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 6 with split 3/3 starts!
# Length of positive trainingset: 2947, length of negative training set: 240
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 6/10 done! It yielded an auc of 217.5739658737795.
#
# Training in iteration 7 with split 1/3 starts!
# Length of positive trainingset: 2942, length of negative training set: 240
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 7 with split 2/3 starts!
# Length of positive trainingset: 2956, length of negative training set: 240
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 7 with split 3/3 starts!
# Length of positive trainingset: 2958, length of negative training set: 240
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Iteration 7/10 done! It yielded an auc of 217.13292481815606.
#
# Training in iteration 8 with split 1/3 starts!
# Length of positive trainingset: 2958, length of negative training set: 240
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 8 with split 2/3 starts!
# Length of positive trainingset: 2948, length of negative training set: 240
# Optimal parameters are C=10 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 8 with split 3/3 starts!
# Length of positive trainingset: 2961, length of negative training set: 240
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Iteration 8/10 done! It yielded an auc of 217.36999147826384.
#
# Results are not getting better. Terminating and using Iteration 5 with an auc of 218.22.
# Training in iteration 1 with split 1/3 starts!
# Length of positive trainingset: 1472, length of negative training set: 221
# Optimal parameters are C=1 and class_weight={0: 30, 1: 10}.
#
# Training in iteration 1 with split 2/3 starts!
# Length of positive trainingset: 1574, length of negative training set: 221
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 1 with split 3/3 starts!
# Length of positive trainingset: 1670, length of negative training set: 222
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Using AUC of pseudo-ROC with x = [0,0.05] as metric.
# Iteration 1/10 done! It yielded an auc of 112.6857402293646.
#
# Training in iteration 2 with split 1/3 starts!
# Length of positive trainingset: 1675, length of negative training set: 221
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 2 with split 2/3 starts!
# Length of positive trainingset: 1670, length of negative training set: 221
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 2 with split 3/3 starts!
# Length of positive trainingset: 1681, length of negative training set: 222
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Iteration 2/10 done! It yielded an auc of 115.44511751317714.
#
# Training in iteration 3 with split 1/3 starts!
# Length of positive trainingset: 1685, length of negative training set: 221
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 3 with split 2/3 starts!
# Length of positive trainingset: 1675, length of negative training set: 221
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 3 with split 3/3 starts!
# Length of positive trainingset: 1668, length of negative training set: 222
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Iteration 3/10 done! It yielded an auc of 115.34117020619772.
#
# Re-ranking complete. Cutting off low ranks.
#
# Training in iteration 4 with split 1/3 starts!
# Length of positive trainingset: 1558, length of negative training set: 174
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 4 with split 2/3 starts!
# Length of positive trainingset: 1562, length of negative training set: 174
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 4 with split 3/3 starts!
# Length of positive trainingset: 1568, length of negative training set: 174
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Iteration 4/10 done! It yielded an auc of 114.37986861652999.
#
# Training in iteration 5 with split 1/3 starts!
# Length of positive trainingset: 1571, length of negative training set: 174
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 5 with split 2/3 starts!
# Length of positive trainingset: 1560, length of negative training set: 174
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 5 with split 3/3 starts!
# Length of positive trainingset: 1575, length of negative training set: 174
# Optimal parameters are C=0.1 and class_weight={0: 30, 1: 10}.
#
# Iteration 5/10 done! It yielded an auc of 113.78576383206665.
#
# Results are not getting better. Terminating and using Iteration 2 with an auc of 115.45.
# Training in iteration 1 with split 1/3 starts!
# Length of positive trainingset: 735, length of negative training set: 115
# Optimal parameters are C=1 and class_weight={0: 30, 1: 10}.
#
# Training in iteration 1 with split 2/3 starts!
# Length of positive trainingset: 776, length of negative training set: 115
# Optimal parameters are C=1 and class_weight={0: 30, 1: 10}.
#
# Training in iteration 1 with split 3/3 starts!
# Length of positive trainingset: 832, length of negative training set: 116
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Using AUC of pseudo-ROC with x = [0,0.05] as metric.
# Iteration 1/10 done! It yielded an auc of 58.30871913018394.
#
# Training in iteration 2 with split 1/3 starts!
# Length of positive trainingset: 832, length of negative training set: 115
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 2 with split 2/3 starts!
# Length of positive trainingset: 827, length of negative training set: 115
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 2 with split 3/3 starts!
# Length of positive trainingset: 839, length of negative training set: 116
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Iteration 2/10 done! It yielded an auc of 58.96335212559844.
#
# Training in iteration 3 with split 1/3 starts!
# Length of positive trainingset: 847, length of negative training set: 115
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 3 with split 2/3 starts!
# Length of positive trainingset: 834, length of negative training set: 115
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 3 with split 3/3 starts!
# Length of positive trainingset: 830, length of negative training set: 116
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Iteration 3/10 done! It yielded an auc of 58.92329140188155.
#
# Re-ranking complete. Cutting off low ranks.
#
# Training in iteration 4 with split 1/3 starts!
# Length of positive trainingset: 822, length of negative training set: 102
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 4 with split 2/3 starts!
# Length of positive trainingset: 813, length of negative training set: 103
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 4 with split 3/3 starts!
# Length of positive trainingset: 825, length of negative training set: 103
# Optimal parameters are C=0.1 and class_weight={0: 30, 1: 10}.
#
# Iteration 4/10 done! It yielded an auc of 58.870150747467925.
#
# Training in iteration 5 with split 1/3 starts!
# Length of positive trainingset: 816, length of negative training set: 102
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 5 with split 2/3 starts!
# Length of positive trainingset: 819, length of negative training set: 103
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 5 with split 3/3 starts!
# Length of positive trainingset: 820, length of negative training set: 103
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Iteration 5/10 done! It yielded an auc of 59.01353452314213.
#
# Training in iteration 6 with split 1/3 starts!
# Length of positive trainingset: 827, length of negative training set: 102
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 6 with split 2/3 starts!
# Length of positive trainingset: 819, length of negative training set: 103
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 6 with split 3/3 starts!
# Length of positive trainingset: 813, length of negative training set: 103
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Iteration 6/10 done! It yielded an auc of 57.67055522327665.
#
# Training in iteration 7 with split 1/3 starts!
# Length of positive trainingset: 816, length of negative training set: 102
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 7 with split 2/3 starts!
# Length of positive trainingset: 819, length of negative training set: 103
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 7 with split 3/3 starts!
# Length of positive trainingset: 820, length of negative training set: 103
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Iteration 7/10 done! It yielded an auc of 58.265059604890055.
#
# Training in iteration 8 with split 1/3 starts!
# Length of positive trainingset: 821, length of negative training set: 102
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 8 with split 2/3 starts!
# Length of positive trainingset: 825, length of negative training set: 103
# Optimal parameters are C=0.1 and class_weight={0: 30, 1: 10}.
#
# Training in iteration 8 with split 3/3 starts!
# Length of positive trainingset: 815, length of negative training set: 103
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Iteration 8/10 done! It yielded an auc of 58.95918923368944.
#
# Results are not getting better. Terminating and using Iteration 5 with an auc of 59.01.
# Training in iteration 1 with split 1/3 starts!
# Length of positive trainingset: 369, length of negative training set: 53
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 1 with split 2/3 starts!
# Length of positive trainingset: 394, length of negative training set: 53
# Optimal parameters are C=0.1 and class_weight={0: 30, 1: 10}.
#
# Training in iteration 1 with split 3/3 starts!
# Length of positive trainingset: 426, length of negative training set: 54
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Using AUC of pseudo-ROC with x = [0,0.05] as metric.
# Iteration 1/10 done! It yielded an auc of 29.696824277707776.
#
# Training in iteration 2 with split 1/3 starts!
# Length of positive trainingset: 430, length of negative training set: 53
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 2 with split 2/3 starts!
# Length of positive trainingset: 431, length of negative training set: 53
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 2 with split 3/3 starts!
# Length of positive trainingset: 434, length of negative training set: 54
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Iteration 2/10 done! It yielded an auc of 29.618545104442948.
#
# Re-ranking complete. Cutting off low ranks.
#
# Training in iteration 3 with split 1/3 starts!
# Length of positive trainingset: 422, length of negative training set: 50
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 3 with split 2/3 starts!
# Length of positive trainingset: 423, length of negative training set: 50
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 3 with split 3/3 starts!
# Length of positive trainingset: 422, length of negative training set: 50
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Iteration 3/10 done! It yielded an auc of 30.489222177191564.
#
# Training in iteration 4 with split 1/3 starts!
# Length of positive trainingset: 423, length of negative training set: 50
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 4 with split 2/3 starts!
# Length of positive trainingset: 418, length of negative training set: 50
# Optimal parameters are C=10 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 4 with split 3/3 starts!
# Length of positive trainingset: 430, length of negative training set: 50
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Iteration 4/10 done! It yielded an auc of 30.189613974142702.
#
# Training in iteration 5 with split 1/3 starts!
# Length of positive trainingset: 423, length of negative training set: 50
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 5 with split 2/3 starts!
# Length of positive trainingset: 420, length of negative training set: 50
# Optimal parameters are C=0.1 and class_weight={0: 30, 1: 10}.
#
# Training in iteration 5 with split 3/3 starts!
# Length of positive trainingset: 423, length of negative training set: 50
# Optimal parameters are C=10 and class_weight={0: 10, 1: 10}.
#
# Iteration 5/10 done! It yielded an auc of 29.560879596707093.
#
# Training in iteration 6 with split 1/3 starts!
# Length of positive trainingset: 424, length of negative training set: 50
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 6 with split 2/3 starts!
# Length of positive trainingset: 423, length of negative training set: 50
# Optimal parameters are C=0.1 and class_weight={0: 30, 1: 10}.
#
# Training in iteration 6 with split 3/3 starts!
# Length of positive trainingset: 424, length of negative training set: 50
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Iteration 6/10 done! It yielded an auc of 29.658521925459315.
#
# Results are not getting better. Terminating and using Iteration 3 with an auc of 30.49.
# Training in iteration 1 with split 1/3 starts!
# Length of positive trainingset: 184, length of negative training set: 28
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 1 with split 2/3 starts!
# Length of positive trainingset: 200, length of negative training set: 29
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 1 with split 3/3 starts!
# Length of positive trainingset: 217, length of negative training set: 29
# Optimal parameters are C=0.1 and class_weight={0: 30, 1: 10}.
#
# Using AUC of pseudo-ROC with x = [0,0.05] as metric.
# Iteration 1/10 done! It yielded an auc of 12.859757246618022.
#
# Training in iteration 2 with split 1/3 starts!
# Length of positive trainingset: 209, length of negative training set: 28
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 2 with split 2/3 starts!
# Length of positive trainingset: 215, length of negative training set: 29
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 2 with split 3/3 starts!
# Length of positive trainingset: 211, length of negative training set: 29
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Iteration 2/10 done! It yielded an auc of 13.370548202580022.
#
# Training in iteration 3 with split 1/3 starts!
# Length of positive trainingset: 211, length of negative training set: 28
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 3 with split 2/3 starts!
# Length of positive trainingset: 213, length of negative training set: 29
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 3 with split 3/3 starts!
# Length of positive trainingset: 210, length of negative training set: 29
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Iteration 3/10 done! It yielded an auc of 14.547443332771843.
#
# Training in iteration 4 with split 1/3 starts!
# Length of positive trainingset: 209, length of negative training set: 28
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 4 with split 2/3 starts!
# Length of positive trainingset: 209, length of negative training set: 29
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 4 with split 3/3 starts!
# Length of positive trainingset: 211, length of negative training set: 29
# Optimal parameters are C=0.1 and class_weight={0: 30, 1: 10}.
#
# Iteration 4/10 done! It yielded an auc of 14.068073174517849.
#
# Re-ranking complete. Cutting off low ranks.
#
# Training in iteration 5 with split 1/3 starts!
# Length of positive trainingset: 204, length of negative training set: 28
# Optimal parameters are C=0.1 and class_weight={0: 30, 1: 10}.
#
# Training in iteration 5 with split 2/3 starts!
# Length of positive trainingset: 211, length of negative training set: 28
# Optimal parameters are C=0.1 and class_weight={0: 30, 1: 10}.
#
# Training in iteration 5 with split 3/3 starts!
# Length of positive trainingset: 205, length of negative training set: 28
# Optimal parameters are C=0.1 and class_weight={0: 30, 1: 10}.
#
# Iteration 5/10 done! It yielded an auc of 14.800400390812788.
#
# Training in iteration 6 with split 1/3 starts!
# Length of positive trainingset: 204, length of negative training set: 28
# Optimal parameters are C=0.1 and class_weight={0: 30, 1: 10}.
#
# Training in iteration 6 with split 2/3 starts!
# Length of positive trainingset: 208, length of negative training set: 28
# Optimal parameters are C=0.1 and class_weight={0: 30, 1: 10}.
#
# Training in iteration 6 with split 3/3 starts!
# Length of positive trainingset: 210, length of negative training set: 28
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Iteration 6/10 done! It yielded an auc of 13.975726359917623.
#
# Training in iteration 7 with split 1/3 starts!
# Length of positive trainingset: 206, length of negative training set: 28
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 7 with split 2/3 starts!
# Length of positive trainingset: 202, length of negative training set: 28
# Optimal parameters are C=0.1 and class_weight={0: 30, 1: 10}.
#
# Training in iteration 7 with split 3/3 starts!
# Length of positive trainingset: 200, length of negative training set: 28
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Iteration 7/10 done! It yielded an auc of 14.807511840637956.
#
# Training in iteration 8 with split 1/3 starts!
# Length of positive trainingset: 204, length of negative training set: 28
# Optimal parameters are C=0.1 and class_weight={0: 30, 1: 10}.
#
# Training in iteration 8 with split 2/3 starts!
# Length of positive trainingset: 198, length of negative training set: 28
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 8 with split 3/3 starts!
# Length of positive trainingset: 201, length of negative training set: 28
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Iteration 8/10 done! It yielded an auc of 14.568741914996114.
#
# Training in iteration 9 with split 1/3 starts!
# Length of positive trainingset: 200, length of negative training set: 28
# Optimal parameters are C=0.1 and class_weight={0: 30, 1: 10}.
#
# Training in iteration 9 with split 2/3 starts!
# Length of positive trainingset: 206, length of negative training set: 28
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 9 with split 3/3 starts!
# Length of positive trainingset: 206, length of negative training set: 28
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Iteration 9/10 done! It yielded an auc of 14.167079265264421.
#
# Training in iteration 10 with split 1/3 starts!
# Length of positive trainingset: 209, length of negative training set: 28
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 10 with split 2/3 starts!
# Length of positive trainingset: 207, length of negative training set: 28
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 10 with split 3/3 starts!
# Length of positive trainingset: 204, length of negative training set: 28
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Iteration 10/10 done! It yielded an auc of 13.994228510814954.
#
# Results are not getting better. Terminating and using Iteration 7 with an auc of 14.81.
# Training in iteration 1 with split 1/3 starts!
# Length of positive trainingset: 97, length of negative training set: 14
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 1 with split 2/3 starts!
# Length of positive trainingset: 99, length of negative training set: 14
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 1 with split 3/3 starts!
# Length of positive trainingset: 103, length of negative training set: 14
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Using AUC of pseudo-ROC with x = [0,0.05] as metric.
# Iteration 1/10 done! It yielded an auc of 7.076319790793261.
#
# Training in iteration 2 with split 1/3 starts!
# Length of positive trainingset: 105, length of negative training set: 14
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 2 with split 2/3 starts!
# Length of positive trainingset: 102, length of negative training set: 14
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 2 with split 3/3 starts!
# Length of positive trainingset: 103, length of negative training set: 14
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Iteration 2/10 done! It yielded an auc of 7.298615815421478.
#
# Training in iteration 3 with split 1/3 starts!
# Length of positive trainingset: 106, length of negative training set: 14
# Optimal parameters are C=0.1 and class_weight={0: 30, 1: 10}.
#
# Training in iteration 3 with split 2/3 starts!
# Length of positive trainingset: 104, length of negative training set: 14
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 3 with split 3/3 starts!
# Length of positive trainingset: 103, length of negative training set: 14
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Iteration 3/10 done! It yielded an auc of 7.0559843293873925.
#
# Re-ranking complete. Cutting off low ranks.
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Training in iteration 4 with split 1/3 starts!
# Length of positive trainingset: 103, length of negative training set: 14
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 4 with split 2/3 starts!
# Length of positive trainingset: 105, length of negative training set: 14
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 4 with split 3/3 starts!
# Length of positive trainingset: 104, length of negative training set: 14
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Iteration 4/10 done! It yielded an auc of 6.543316841333567.
#
# Training in iteration 5 with split 1/3 starts!
# Length of positive trainingset: 106, length of negative training set: 14
# Optimal parameters are C=0.1 and class_weight={0: 30, 1: 10}.
#
# Training in iteration 5 with split 2/3 starts!
# Length of positive trainingset: 94, length of negative training set: 14
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 5 with split 3/3 starts!
# Length of positive trainingset: 96, length of negative training set: 14
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Iteration 5/10 done! It yielded an auc of 6.0926036750075845.
#
# Results are not getting better. Terminating and using Iteration 2 with an auc of 7.3.
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Training in iteration 1 with split 1/3 starts!
# Length of positive trainingset: 45, length of negative training set: 6
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 1 with split 2/3 starts!
# Length of positive trainingset: 52, length of negative training set: 7
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 1 with split 3/3 starts!
# Length of positive trainingset: 55, length of negative training set: 7
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Using AUC of pseudo-ROC with x = [0,0.05] as metric.
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Iteration 1/10 done! It yielded an auc of 3.7392607848148183.
#
# Training in iteration 2 with split 1/3 starts!
# Length of positive trainingset: 55, length of negative training set: 6
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 2 with split 2/3 starts!
# Length of positive trainingset: 55, length of negative training set: 7
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 2 with split 3/3 starts!
# Length of positive trainingset: 56, length of negative training set: 7
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Iteration 2/10 done! It yielded an auc of 3.6781464605425986.
#
# Re-ranking complete. Cutting off low ranks.
#
# Training in iteration 3 with split 1/3 starts!
# Length of positive trainingset: 55, length of negative training set: 6
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 3 with split 2/3 starts!
# Length of positive trainingset: 51, length of negative training set: 7
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 3 with split 3/3 starts!
# Length of positive trainingset: 51, length of negative training set: 7
# Optimal parameters are C=0.1 and class_weight={0: 30, 1: 10}.
#
# Iteration 3/10 done! It yielded an auc of 3.3874802381320466.
#
# Training in iteration 4 with split 1/3 starts!
# Length of positive trainingset: 53, length of negative training set: 6
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 4 with split 2/3 starts!
# Length of positive trainingset: 50, length of negative training set: 7
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 4 with split 3/3 starts!
# Length of positive trainingset: 49, length of negative training set: 7
# Optimal parameters are C=0.1 and class_weight={0: 30, 1: 10}.
#
# Iteration 4/10 done! It yielded an auc of 3.691112969702453.
#
# Results are not getting better. Terminating and using Iteration 1 with an auc of 3.74.
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Dataset too small. There are not enough positive or negative examples to perform nested cross-validation.
# Dataset too small: 48 PSMs. Quitting evaluation.

# %%
fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8])
plt.ylim(0,1.1)
x = range(iters)
y = [e/l for e,l in zip(pExpectIdents,pLen)]
ax.plot(x, y)
ax.set_xlabel('size of dataset')
ax.set_title('portion of dataset with an expected q-value of less than 1%')
ax.set_xticks(x)
ax.set_xticklabels(pLen)
# Out:
# [Text(0, 0, '4915'),
#  Text(0, 0, '2745'),
#  Text(0, 0, '1461'),
#  Text(0, 0, '738'),
#  Text(0, 0, '373'),
#  Text(0, 0, '188'),
#  Text(0, 0, '95')]

# %%
fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8])
yUpper = max(2 - min(y), max(y)) + 0.1
ax.set_ylim(2 - yUpper, yUpper)
x = range(iters)
y = [i/e if (e != 0) else np.nan for i,e in zip(pIdents, pExpectIdents)]
ax.plot(x, y)
ax.set_xlabel('size of dataset')
ax.set_title('number of found / number of expected idents at 1% q-value')
ax.set_xticks(x)
ax.set_xticklabels(oriLen)
plt.show()

# %%
x = range(iters)
ratioAUCs = [p / o if (o!=0) else p + 1 for p,o in zip(pAUCs,oriAUCs)]
ratioIdents = [p / o for p,o in zip(pIdents,oriIdents)]

fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8])
yUpper = max(2 - min([a for a in ratioAUCs if a != 0]), max(ratioAUCs)) + 0.1
ax.set_ylim(2 - yUpper, yUpper)
ax.plot(x, ratioAUCs)
ax.set_xlabel('size of dataset')
ax.set_title('Ratio of AUCs of percolator vs NuXL')
ax.set_xticks(x)
ax.set_xticklabels(pLen)
plt.show()

fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8])
yUpper = max(2 - min(ratioIdents), max(ratioIdents)) + 0.1
ax.set_ylim(2 - yUpper, yUpper)
ax.plot(x,ratioIdents)
ax.set_xlabel('size of dataset')
ax.set_title('Ratio of Idents at 1% of percolator vs NuXL')
ax.set_xticks(x)
ax.set_xticklabels(pLen)
plt.show()
