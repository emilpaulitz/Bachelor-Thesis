# %%
# %%time
from pycolator import *

idCol = 'SpecId'
scoreCol = 'NuXL:score'
excluded = ['SpecId', 'Label', 'ScanNr', 'Peptide', 'Proteins', 'FDR', 'q-val', 'class-specific_q-val', 'Rank', 'temp_score', 'percolator_score']

dSlow = readAndProcess('../data/1-AChernev_080219_dir_HeLa_cyt_UCGA_slow.tsv', idCol, scoreCol, excludedCols = excluded)
features = [x for x in list(dSlow.columns) if (x not in excluded)]
# Out:
# file read...
# strings converted to floats...
# q-values estimated...
# ranks computed...
# features normed...
# floats converted to ints...
# file ready!
# Wall time: 15.6 s

# %%
# %%time

oriIdents = []
oriAUCs = []
dxl = dSlow.loc[dSlow['NuXL:isXL'] == 1]
    
for portion in range(13):
    ix = list(dxl.index)
    newIx = [x for i,x in enumerate(ix) if (i % (pow(2,portion)) == 0)]
    oriAUCs.append(pseudoROC(dxl.loc[newIx], label = '', plot = False))
    oriIdents.append(len(dxl.loc[dxl.index.isin(newIx) & (dxl['q-val'] <= 0.01)]))
# Out:
# Wall time: 764 ms

# %%
# %%time
import math

aucs = []
idents = []
dxl = dSlow.loc[dSlow['NuXL:isXL'] == 1]

saveName = ''

for portion in range(13):
    print('len / 2^{} => Using {} PSMs:\n'.format(portion, math.floor(len(dxl) / pow(2,portion))))
    dxl = dSlow.loc[dSlow['NuXL:isXL'] == 1]
    
    ix = list(dxl.index)
    newIx = [x for i,x in enumerate(ix) if (i % (math.pow(2,portion)) == 0)]
    
    pxl = percolator_experimental(dxl.loc[newIx], idCol, features, plotSaveName = saveName, plotXLnXL = False)
    
    auct = pseudoROC(pxl, label = '', plot = False)
    aucs.append(auct)
    idents.append(len(pxl.loc[pxl['q-val'] <= 0.01]))
# Out:
# len / 2^0 => Using 51521 PSMs:
#
# Training in iteration 1 with split 1/3 starts!
# Length of positive trainingset: 3013, length of negative training set: 14667
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 1 with split 2/3 starts!
# Length of positive trainingset: 3220, length of negative training set: 14667
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 1 with split 3/3 starts!
# Length of positive trainingset: 3657, length of negative training set: 14668
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Using AUC of pseudo-ROC with x = [0,0.05] as metric.
# Iteration 1/10 done! It yielded an auc of 234.55571015637727.
#
# Training in iteration 2 with split 1/3 starts!
# Length of positive trainingset: 3761, length of negative training set: 14667
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 2 with split 2/3 starts!
# Length of positive trainingset: 3865, length of negative training set: 14667
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 2 with split 3/3 starts!
# Length of positive trainingset: 4174, length of negative training set: 14668
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Iteration 2/10 done! It yielded an auc of 262.4360789819086.
#
# Training in iteration 3 with split 1/3 starts!
# Length of positive trainingset: 4241, length of negative training set: 14667
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 3 with split 2/3 starts!
# Length of positive trainingset: 4319, length of negative training set: 14667
# Optimal parameters are C=10 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 3 with split 3/3 starts!
# Length of positive trainingset: 4477, length of negative training set: 14668
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Iteration 3/10 done! It yielded an auc of 279.8111920480175.
#
# Training in iteration 4 with split 1/3 starts!
# Length of positive trainingset: 4478, length of negative training set: 14667
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 4 with split 2/3 starts!
# Length of positive trainingset: 4500, length of negative training set: 14667
# Optimal parameters are C=10 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 4 with split 3/3 starts!
# Length of positive trainingset: 4560, length of negative training set: 14668
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 4/10 done! It yielded an auc of 284.7904623838635.
#
# Training in iteration 5 with split 1/3 starts!
# Length of positive trainingset: 4610, length of negative training set: 14667
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 5 with split 2/3 starts!
# Length of positive trainingset: 4509, length of negative training set: 14667
# Optimal parameters are C=10 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 5 with split 3/3 starts!
# Length of positive trainingset: 4674, length of negative training set: 14668
# Optimal parameters are C=10 and class_weight={0: 10, 1: 10}.
#
# Iteration 5/10 done! It yielded an auc of 287.68058218299666.
#
# Training in iteration 6 with split 1/3 starts!
# Length of positive trainingset: 4655, length of negative training set: 14667
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 6 with split 2/3 starts!
# Length of positive trainingset: 4598, length of negative training set: 14667
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 6 with split 3/3 starts!
# Length of positive trainingset: 4605, length of negative training set: 14668
# Optimal parameters are C=10 and class_weight={0: 10, 1: 10}.
#
# Iteration 6/10 done! It yielded an auc of 288.21276176313296.
#
# Re-ranking complete. Cutting off low ranks.
#
# Training in iteration 7 with split 1/3 starts!
# Length of positive trainingset: 3938, length of negative training set: 7226
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 7 with split 2/3 starts!
# Length of positive trainingset: 4067, length of negative training set: 7226
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 7 with split 3/3 starts!
# Length of positive trainingset: 4071, length of negative training set: 7226
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 7/10 done! It yielded an auc of 292.70799494460323.
#
# Training in iteration 8 with split 1/3 starts!
# Length of positive trainingset: 4120, length of negative training set: 7226
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 8 with split 2/3 starts!
# Length of positive trainingset: 4119, length of negative training set: 7226
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 8 with split 3/3 starts!
# Length of positive trainingset: 4169, length of negative training set: 7226
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 8/10 done! It yielded an auc of 293.51858526238516.
#
# Training in iteration 9 with split 1/3 starts!
# Length of positive trainingset: 4171, length of negative training set: 7226
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 9 with split 2/3 starts!
# Length of positive trainingset: 4079, length of negative training set: 7226
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 9 with split 3/3 starts!
# Length of positive trainingset: 4177, length of negative training set: 7226
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 9/10 done! It yielded an auc of 294.2841368909754.
#
# Training in iteration 10 with split 1/3 starts!
# Length of positive trainingset: 4159, length of negative training set: 7226
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 10 with split 2/3 starts!
# Length of positive trainingset: 4159, length of negative training set: 7226
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 10 with split 3/3 starts!
# Length of positive trainingset: 4151, length of negative training set: 7226
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 10/10 done! It yielded an auc of 293.09907235809624.
#
# Terminating and using Iteration 9 with an auc of 294.28.
# len / 2^1 => Using 25760 PSMs:
#
# Training in iteration 1 with split 1/3 starts!
# Length of positive trainingset: 1483, length of negative training set: 7362
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 1 with split 2/3 starts!
# Length of positive trainingset: 1539, length of negative training set: 7362
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 1 with split 3/3 starts!
# Length of positive trainingset: 1758, length of negative training set: 7362
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Using AUC of pseudo-ROC with x = [0,0.05] as metric.
# Iteration 1/10 done! It yielded an auc of 118.01018899726266.
#
# Training in iteration 2 with split 1/3 starts!
# Length of positive trainingset: 1794, length of negative training set: 7362
# Optimal parameters are C=10 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 2 with split 2/3 starts!
# Length of positive trainingset: 1982, length of negative training set: 7362
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 2 with split 3/3 starts!
# Length of positive trainingset: 2135, length of negative training set: 7362
# Optimal parameters are C=10 and class_weight={0: 10, 1: 10}.
#
# Iteration 2/10 done! It yielded an auc of 138.1656472432413.
#
# Training in iteration 3 with split 1/3 starts!
# Length of positive trainingset: 2130, length of negative training set: 7362
# Optimal parameters are C=10 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 3 with split 2/3 starts!
# Length of positive trainingset: 2103, length of negative training set: 7362
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 3 with split 3/3 starts!
# Length of positive trainingset: 2159, length of negative training set: 7362
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 3/10 done! It yielded an auc of 143.41334938409275.
#
# Training in iteration 4 with split 1/3 starts!
# Length of positive trainingset: 2186, length of negative training set: 7362
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 4 with split 2/3 starts!
# Length of positive trainingset: 2149, length of negative training set: 7362
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 4 with split 3/3 starts!
# Length of positive trainingset: 2214, length of negative training set: 7362
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 4/10 done! It yielded an auc of 147.16340936068696.
#
# Training in iteration 5 with split 1/3 starts!
# Length of positive trainingset: 2213, length of negative training set: 7362
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 5 with split 2/3 starts!
# Length of positive trainingset: 2223, length of negative training set: 7362
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 5 with split 3/3 starts!
# Length of positive trainingset: 2283, length of negative training set: 7362
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 5/10 done! It yielded an auc of 149.82121902102713.
#
# Training in iteration 6 with split 1/3 starts!
# Length of positive trainingset: 2251, length of negative training set: 7362
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 6 with split 2/3 starts!
# Length of positive trainingset: 2262, length of negative training set: 7362
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 6 with split 3/3 starts!
# Length of positive trainingset: 2277, length of negative training set: 7362
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 6/10 done! It yielded an auc of 150.04602304099583.
#
# Re-ranking complete. Cutting off low ranks.
#
# Training in iteration 7 with split 1/3 starts!
# Length of positive trainingset: 2092, length of negative training set: 5593
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 7 with split 2/3 starts!
# Length of positive trainingset: 2108, length of negative training set: 5593
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 7 with split 3/3 starts!
# Length of positive trainingset: 2156, length of negative training set: 5594
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 7/10 done! It yielded an auc of 149.99816880939244.
#
# Training in iteration 8 with split 1/3 starts!
# Length of positive trainingset: 2164, length of negative training set: 5593
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 8 with split 2/3 starts!
# Length of positive trainingset: 2178, length of negative training set: 5593
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 8 with split 3/3 starts!
# Length of positive trainingset: 2143, length of negative training set: 5594
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 8/10 done! It yielded an auc of 151.7292334065656.
#
# Training in iteration 9 with split 1/3 starts!
# Length of positive trainingset: 2212, length of negative training set: 5593
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 9 with split 2/3 starts!
# Length of positive trainingset: 2168, length of negative training set: 5593
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 9 with split 3/3 starts!
# Length of positive trainingset: 2201, length of negative training set: 5594
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 9/10 done! It yielded an auc of 152.2982658295583.
#
# Training in iteration 10 with split 1/3 starts!
# Length of positive trainingset: 2146, length of negative training set: 5593
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 10 with split 2/3 starts!
# Length of positive trainingset: 2223, length of negative training set: 5593
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 10 with split 3/3 starts!
# Length of positive trainingset: 2173, length of negative training set: 5594
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Iteration 10/10 done! It yielded an auc of 151.06537476256625.
#
# Terminating and using Iteration 9 with an auc of 152.3.
# len / 2^2 => Using 12880 PSMs:
#
# Training in iteration 1 with split 1/3 starts!
# Length of positive trainingset: 737, length of negative training set: 3712
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 1 with split 2/3 starts!
# Length of positive trainingset: 852, length of negative training set: 3712
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 1 with split 3/3 starts!
# Length of positive trainingset: 948, length of negative training set: 3712
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Using AUC of pseudo-ROC with x = [0,0.05] as metric.
# Iteration 1/10 done! It yielded an auc of 66.32533964718341.
#
# Training in iteration 2 with split 1/3 starts!
# Length of positive trainingset: 1017, length of negative training set: 3712
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 2 with split 2/3 starts!
# Length of positive trainingset: 1001, length of negative training set: 3712
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 2 with split 3/3 starts!
# Length of positive trainingset: 1115, length of negative training set: 3712
# Optimal parameters are C=10 and class_weight={0: 10, 1: 10}.
#
# Iteration 2/10 done! It yielded an auc of 74.73507051641313.
#
# Training in iteration 3 with split 1/3 starts!
# Length of positive trainingset: 1113, length of negative training set: 3712
# Optimal parameters are C=10 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 3 with split 2/3 starts!
# Length of positive trainingset: 1116, length of negative training set: 3712
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 3 with split 3/3 starts!
# Length of positive trainingset: 1113, length of negative training set: 3712
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Iteration 3/10 done! It yielded an auc of 76.06640987309143.
#
# Training in iteration 4 with split 1/3 starts!
# Length of positive trainingset: 1095, length of negative training set: 3712
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 4 with split 2/3 starts!
# Length of positive trainingset: 1108, length of negative training set: 3712
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 4 with split 3/3 starts!
# Length of positive trainingset: 1117, length of negative training set: 3712
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Iteration 4/10 done! It yielded an auc of 77.58594372089786.
#
# Training in iteration 5 with split 1/3 starts!
# Length of positive trainingset: 1167, length of negative training set: 3712
# Optimal parameters are C=10 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 5 with split 2/3 starts!
# Length of positive trainingset: 1124, length of negative training set: 3712
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 5 with split 3/3 starts!
# Length of positive trainingset: 1134, length of negative training set: 3712
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Iteration 5/10 done! It yielded an auc of 77.02301442655116.
#
# Re-ranking complete. Cutting off low ranks.
#
# Training in iteration 6 with split 1/3 starts!
# Length of positive trainingset: 1105, length of negative training set: 3261
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 6 with split 2/3 starts!
# Length of positive trainingset: 1090, length of negative training set: 3261
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 6 with split 3/3 starts!
# Length of positive trainingset: 1097, length of negative training set: 3262
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 6/10 done! It yielded an auc of 78.08610632512828.
#
# Training in iteration 7 with split 1/3 starts!
# Length of positive trainingset: 1089, length of negative training set: 3261
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 7 with split 2/3 starts!
# Length of positive trainingset: 1133, length of negative training set: 3261
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 7 with split 3/3 starts!
# Length of positive trainingset: 1109, length of negative training set: 3262
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 7/10 done! It yielded an auc of 78.79829513403946.
#
# Training in iteration 8 with split 1/3 starts!
# Length of positive trainingset: 1133, length of negative training set: 3261
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 8 with split 2/3 starts!
# Length of positive trainingset: 1091, length of negative training set: 3261
# Optimal parameters are C=10 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 8 with split 3/3 starts!
# Length of positive trainingset: 1074, length of negative training set: 3262
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 8/10 done! It yielded an auc of 77.34428847494031.
#
# Training in iteration 9 with split 1/3 starts!
# Length of positive trainingset: 1087, length of negative training set: 3261
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 9 with split 2/3 starts!
# Length of positive trainingset: 1138, length of negative training set: 3261
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 9 with split 3/3 starts!
# Length of positive trainingset: 1109, length of negative training set: 3262
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 9/10 done! It yielded an auc of 77.71568892979509.
#
# Training in iteration 10 with split 1/3 starts!
# Length of positive trainingset: 1133, length of negative training set: 3261
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 10 with split 2/3 starts!
# Length of positive trainingset: 1092, length of negative training set: 3261
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 10 with split 3/3 starts!
# Length of positive trainingset: 1140, length of negative training set: 3262
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Iteration 10/10 done! It yielded an auc of 77.76681010827765.
#
# Results are not getting better. Terminating and using Iteration 7 with an auc of 78.8.
# len / 2^3 => Using 6440 PSMs:
#
# Training in iteration 1 with split 1/3 starts!
# Length of positive trainingset: 391, length of negative training set: 1882
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 1 with split 2/3 starts!
# Length of positive trainingset: 406, length of negative training set: 1882
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 1 with split 3/3 starts!
# Length of positive trainingset: 518, length of negative training set: 1882
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Using AUC of pseudo-ROC with x = [0,0.05] as metric.
# Iteration 1/10 done! It yielded an auc of 34.06610002151454.
#
# Training in iteration 2 with split 1/3 starts!
# Length of positive trainingset: 510, length of negative training set: 1882
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 2 with split 2/3 starts!
# Length of positive trainingset: 523, length of negative training set: 1882
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 2 with split 3/3 starts!
# Length of positive trainingset: 569, length of negative training set: 1882
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Iteration 2/10 done! It yielded an auc of 39.158204805586266.
#
# Training in iteration 3 with split 1/3 starts!
# Length of positive trainingset: 579, length of negative training set: 1882
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 3 with split 2/3 starts!
# Length of positive trainingset: 569, length of negative training set: 1882
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 3 with split 3/3 starts!
# Length of positive trainingset: 586, length of negative training set: 1882
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 3/10 done! It yielded an auc of 39.70153854124565.
#
# Training in iteration 4 with split 1/3 starts!
# Length of positive trainingset: 586, length of negative training set: 1882
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 4 with split 2/3 starts!
# Length of positive trainingset: 574, length of negative training set: 1882
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 4 with split 3/3 starts!
# Length of positive trainingset: 588, length of negative training set: 1882
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Iteration 4/10 done! It yielded an auc of 39.722012367192626.
#
# Re-ranking complete. Cutting off low ranks.
#
# Training in iteration 5 with split 1/3 starts!
# Length of positive trainingset: 568, length of negative training set: 1758
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 5 with split 2/3 starts!
# Length of positive trainingset: 567, length of negative training set: 1758
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 5 with split 3/3 starts!
# Length of positive trainingset: 559, length of negative training set: 1758
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Iteration 5/10 done! It yielded an auc of 39.38472653001582.
#
# Training in iteration 6 with split 1/3 starts!
# Length of positive trainingset: 566, length of negative training set: 1758
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 6 with split 2/3 starts!
# Length of positive trainingset: 595, length of negative training set: 1758
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 6 with split 3/3 starts!
# Length of positive trainingset: 569, length of negative training set: 1758
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 6/10 done! It yielded an auc of 40.44936989543594.
#
# Training in iteration 7 with split 1/3 starts!
# Length of positive trainingset: 581, length of negative training set: 1758
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 7 with split 2/3 starts!
# Length of positive trainingset: 583, length of negative training set: 1758
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 7 with split 3/3 starts!
# Length of positive trainingset: 578, length of negative training set: 1758
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 7/10 done! It yielded an auc of 41.65383260792059.
#
# Training in iteration 8 with split 1/3 starts!
# Length of positive trainingset: 604, length of negative training set: 1758
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 8 with split 2/3 starts!
# Length of positive trainingset: 565, length of negative training set: 1758
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 8 with split 3/3 starts!
# Length of positive trainingset: 601, length of negative training set: 1758
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Iteration 8/10 done! It yielded an auc of 40.87589063092615.
#
# Training in iteration 9 with split 1/3 starts!
# Length of positive trainingset: 578, length of negative training set: 1758
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 9 with split 2/3 starts!
# Length of positive trainingset: 572, length of negative training set: 1758
# Optimal parameters are C=10 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 9 with split 3/3 starts!
# Length of positive trainingset: 589, length of negative training set: 1758
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Iteration 9/10 done! It yielded an auc of 41.089271102774845.
#
# Training in iteration 10 with split 1/3 starts!
# Length of positive trainingset: 597, length of negative training set: 1758
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 10 with split 2/3 starts!
# Length of positive trainingset: 580, length of negative training set: 1758
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 10 with split 3/3 starts!
# Length of positive trainingset: 571, length of negative training set: 1758
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 10/10 done! It yielded an auc of 41.499544518681454.
#
# Results are not getting better. Terminating and using Iteration 7 with an auc of 41.65.
# len / 2^4 => Using 3220 PSMs:
#
# Training in iteration 1 with split 1/3 starts!
# Length of positive trainingset: 178, length of negative training set: 929
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 1 with split 2/3 starts!
# Length of positive trainingset: 212, length of negative training set: 929
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 1 with split 3/3 starts!
# Length of positive trainingset: 246, length of negative training set: 930
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Using AUC of pseudo-ROC with x = [0,0.05] as metric.
# Iteration 1/10 done! It yielded an auc of 15.534985093625949.
#
# Training in iteration 2 with split 1/3 starts!
# Length of positive trainingset: 240, length of negative training set: 929
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 2 with split 2/3 starts!
# Length of positive trainingset: 244, length of negative training set: 929
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 2 with split 3/3 starts!
# Length of positive trainingset: 259, length of negative training set: 930
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Iteration 2/10 done! It yielded an auc of 17.05875701522652.
#
# Training in iteration 3 with split 1/3 starts!
# Length of positive trainingset: 250, length of negative training set: 929
# Optimal parameters are C=1 and class_weight={0: 30, 1: 10}.
#
# Training in iteration 3 with split 2/3 starts!
# Length of positive trainingset: 270, length of negative training set: 929
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 3 with split 3/3 starts!
# Length of positive trainingset: 264, length of negative training set: 930
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Iteration 3/10 done! It yielded an auc of 17.092037467506103.
#
# Re-ranking complete. Cutting off low ranks.
#
# Training in iteration 4 with split 1/3 starts!
# Length of positive trainingset: 255, length of negative training set: 898
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 4 with split 2/3 starts!
# Length of positive trainingset: 250, length of negative training set: 899
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 4 with split 3/3 starts!
# Length of positive trainingset: 261, length of negative training set: 899
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Iteration 4/10 done! It yielded an auc of 18.855379301362625.
#
# Training in iteration 5 with split 1/3 starts!
# Length of positive trainingset: 273, length of negative training set: 898
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 5 with split 2/3 starts!
# Length of positive trainingset: 275, length of negative training set: 899
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 5 with split 3/3 starts!
# Length of positive trainingset: 291, length of negative training set: 899
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Iteration 5/10 done! It yielded an auc of 18.638073321938645.
#
# Training in iteration 6 with split 1/3 starts!
# Length of positive trainingset: 294, length of negative training set: 898
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 6 with split 2/3 starts!
# Length of positive trainingset: 284, length of negative training set: 899
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 6 with split 3/3 starts!
# Length of positive trainingset: 297, length of negative training set: 899
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Iteration 6/10 done! It yielded an auc of 18.393894370591887.
#
# Training in iteration 7 with split 1/3 starts!
# Length of positive trainingset: 291, length of negative training set: 898
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 7 with split 2/3 starts!
# Length of positive trainingset: 282, length of negative training set: 899
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 7 with split 3/3 starts!
# Length of positive trainingset: 256, length of negative training set: 899
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Iteration 7/10 done! It yielded an auc of 18.022858162282805.
#
# Results are not getting better. Terminating and using Iteration 4 with an auc of 18.86.
# len / 2^5 => Using 1610 PSMs:
#
# Training in iteration 1 with split 1/3 starts!
# Length of positive trainingset: 89, length of negative training set: 464
# Optimal parameters are C=0.1 and class_weight={0: 30, 1: 10}.
#
# Training in iteration 1 with split 2/3 starts!
# Length of positive trainingset: 127, length of negative training set: 465
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 1 with split 3/3 starts!
# Length of positive trainingset: 145, length of negative training set: 465
# Optimal parameters are C=10 and class_weight={0: 30, 1: 10}.
#
# Using AUC of pseudo-ROC with x = [0,0.05] as metric.
# Iteration 1/10 done! It yielded an auc of 8.630345109081023.
#
# Training in iteration 2 with split 1/3 starts!
# Length of positive trainingset: 126, length of negative training set: 464
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 2 with split 2/3 starts!
# Length of positive trainingset: 139, length of negative training set: 465
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 2 with split 3/3 starts!
# Length of positive trainingset: 165, length of negative training set: 465
# Optimal parameters are C=1 and class_weight={0: 30, 1: 10}.
#
# Iteration 2/10 done! It yielded an auc of 9.987267643953718.
#
# Training in iteration 3 with split 1/3 starts!
# Length of positive trainingset: 147, length of negative training set: 464
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 3 with split 2/3 starts!
# Length of positive trainingset: 147, length of negative training set: 465
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 3 with split 3/3 starts!
# Length of positive trainingset: 171, length of negative training set: 465
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Iteration 3/10 done! It yielded an auc of 10.265783969915143.
#
# Training in iteration 4 with split 1/3 starts!
# Length of positive trainingset: 159, length of negative training set: 464
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 4 with split 2/3 starts!
# Length of positive trainingset: 156, length of negative training set: 465
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 4 with split 3/3 starts!
# Length of positive trainingset: 143, length of negative training set: 465
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Iteration 4/10 done! It yielded an auc of 10.829600406002342.
#
# Training in iteration 5 with split 1/3 starts!
# Length of positive trainingset: 149, length of negative training set: 464
# Optimal parameters are C=1 and class_weight={0: 30, 1: 10}.
#
# Training in iteration 5 with split 2/3 starts!
# Length of positive trainingset: 166, length of negative training set: 465
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 5 with split 3/3 starts!
# Length of positive trainingset: 158, length of negative training set: 465
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Iteration 5/10 done! It yielded an auc of 10.453316563114683.
#
# Re-ranking complete. Cutting off low ranks.
#
# Training in iteration 6 with split 1/3 starts!
# Length of positive trainingset: 169, length of negative training set: 458
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 6 with split 2/3 starts!
# Length of positive trainingset: 141, length of negative training set: 459
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 6 with split 3/3 starts!
# Length of positive trainingset: 152, length of negative training set: 459
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Iteration 6/10 done! It yielded an auc of 10.310011944431569.
#
# Training in iteration 7 with split 1/3 starts!
# Length of positive trainingset: 159, length of negative training set: 458
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 7 with split 2/3 starts!
# Length of positive trainingset: 144, length of negative training set: 459
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 7 with split 3/3 starts!
# Length of positive trainingset: 162, length of negative training set: 459
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Iteration 7/10 done! It yielded an auc of 10.055614646075554.
#
# Results are not getting better. Terminating and using Iteration 4 with an auc of 10.83.
# len / 2^6 => Using 805 PSMs:
#
# Training in iteration 1 with split 1/3 starts!
# Length of positive trainingset: 48, length of negative training set: 230
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 1 with split 2/3 starts!
# Length of positive trainingset: 65, length of negative training set: 231
# Optimal parameters are C=1 and class_weight={0: 30, 1: 10}.
#
# Training in iteration 1 with split 3/3 starts!
# Length of positive trainingset: 73, length of negative training set: 231
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Using AUC of pseudo-ROC with x = [0,0.05] as metric.
# Iteration 1/10 done! It yielded an auc of 4.254014588907371.
#
# Training in iteration 2 with split 1/3 starts!
# Length of positive trainingset: 68, length of negative training set: 230
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 2 with split 2/3 starts!
# Length of positive trainingset: 72, length of negative training set: 231
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 2 with split 3/3 starts!
# Length of positive trainingset: 83, length of negative training set: 231
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Iteration 2/10 done! It yielded an auc of 4.418866444614706.
#
# Training in iteration 3 with split 1/3 starts!
# Length of positive trainingset: 75, length of negative training set: 230
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 3 with split 2/3 starts!
# Length of positive trainingset: 67, length of negative training set: 231
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 3 with split 3/3 starts!
# Length of positive trainingset: 70, length of negative training set: 231
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Iteration 3/10 done! It yielded an auc of 3.364716986319329.
#
# Re-ranking complete. Cutting off low ranks.
#
# Training in iteration 4 with split 1/3 starts!
# Length of positive trainingset: 55, length of negative training set: 228
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 4 with split 2/3 starts!
# Length of positive trainingset: 56, length of negative training set: 228
# Optimal parameters are C=10 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 4 with split 3/3 starts!
# Length of positive trainingset: 57, length of negative training set: 228
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Iteration 4/10 done! It yielded an auc of 3.8139627211327234.
#
# Training in iteration 5 with split 1/3 starts!
# Length of positive trainingset: 63, length of negative training set: 228
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 5 with split 2/3 starts!
# Length of positive trainingset: 70, length of negative training set: 228
# Optimal parameters are C=1 and class_weight={0: 30, 1: 10}.
#
# Training in iteration 5 with split 3/3 starts!
# Length of positive trainingset: 61, length of negative training set: 228
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Iteration 5/10 done! It yielded an auc of 3.9348285446386697.
#
# Results are not getting better. Terminating and using Iteration 2 with an auc of 4.42.
# len / 2^7 => Using 402 PSMs:
#
# Training in iteration 1 with split 1/3 starts!
# Length of positive trainingset: 24, length of negative training set: 113
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 1 with split 2/3 starts!
# Length of positive trainingset: 24, length of negative training set: 113
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 1 with split 3/3 starts!
# Length of positive trainingset: 24, length of negative training set: 114
# Optimal parameters are C=10 and class_weight={0: 10, 1: 10}.
#
# Using AUC of pseudo-ROC with x = [0,0.05] as metric.
# Iteration 1/10 done! It yielded an auc of 1.9018292682926845.
#
# Training in iteration 2 with split 1/3 starts!
# Length of positive trainingset: 29, length of negative training set: 113
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 2 with split 2/3 starts!
# Length of positive trainingset: 24, length of negative training set: 113
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 2 with split 3/3 starts!
# Length of positive trainingset: 31, length of negative training set: 114
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Optimal parameters are C=1 and class_weight={0: 30, 1: 10}.
#
# Iteration 2/10 done! It yielded an auc of 1.8762755102040838.
#
# Re-ranking complete. Cutting off low ranks.
#
# Training in iteration 3 with split 1/3 starts!
# Length of positive trainingset: 32, length of negative training set: 113
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 3 with split 2/3 starts!
# Length of positive trainingset: 33, length of negative training set: 113
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 3 with split 3/3 starts!
# Length of positive trainingset: 20, length of negative training set: 114
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Optimal parameters are C=10 and class_weight={0: 30, 1: 10}.
#
# Iteration 3/10 done! It yielded an auc of 1.6519138755980847.
#
# Training in iteration 4 with split 1/3 starts!
# Length of positive trainingset: 22, length of negative training set: 113
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 4 with split 2/3 starts!
# Length of positive trainingset: 27, length of negative training set: 113
# Optimal parameters are C=0.1 and class_weight={0: 30, 1: 10}.
#
# Training in iteration 4 with split 3/3 starts!
# Length of positive trainingset: 34, length of negative training set: 114
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Optimal parameters are C=0.1 and class_weight={0: 30, 1: 10}.
#
# Iteration 4/10 done! It yielded an auc of 1.77663671373556.
#
# Results are not getting better. Terminating and using Iteration 1 with an auc of 1.9.
# len / 2^8 => Using 201 PSMs:
#
# Training in iteration 1 with split 1/3 starts!
# Length of positive trainingset: 13, length of negative training set: 52
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 1 with split 2/3 starts!
# Length of positive trainingset: 12, length of negative training set: 53
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 1 with split 3/3 starts!
# Length of positive trainingset: 14, length of negative training set: 53
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Using AUC of pseudo-ROC with x = [0,0.05] as metric.
# Iteration 1/10 done! It yielded an auc of 0.8703703703703716.
#
# Training in iteration 2 with split 1/3 starts!
# Length of positive trainingset: 20, length of negative training set: 52
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 2 with split 2/3 starts!
# Length of positive trainingset: 15, length of negative training set: 53
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 2 with split 3/3 starts!
# Length of positive trainingset: 18, length of negative training set: 53
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Iteration 2/10 done! It yielded an auc of 0.946428571428571.
#
# Training in iteration 3 with split 1/3 starts!
# Length of positive trainingset: 16, length of negative training set: 52
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 3 with split 2/3 starts!
# Length of positive trainingset: 24, length of negative training set: 53
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 3 with split 3/3 starts!
# Length of positive trainingset: 18, length of negative training set: 53
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Iteration 3/10 done! It yielded an auc of 0.946428571428571.
#
# Re-ranking complete. Cutting off low ranks.
#
# Training in iteration 4 with split 1/3 starts!
# Length of positive trainingset: 22, length of negative training set: 52
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 4 with split 2/3 starts!
# Length of positive trainingset: 14, length of negative training set: 53
# Optimal parameters are C=1 and class_weight={0: 30, 1: 10}.
#
# Training in iteration 4 with split 3/3 starts!
# Length of positive trainingset: 17, length of negative training set: 53
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Iteration 4/10 done! It yielded an auc of 0.946428571428571.
#
# Training in iteration 5 with split 1/3 starts!
# Length of positive trainingset: 15, length of negative training set: 52
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 5 with split 2/3 starts!
# Length of positive trainingset: 21, length of negative training set: 53
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 5 with split 3/3 starts!
# Length of positive trainingset: 18, length of negative training set: 53
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Optimal parameters are C=1 and class_weight={0: 30, 1: 10}.
#
# Iteration 5/10 done! It yielded an auc of 0.9400000000000008.
#
# Results are not getting better. Terminating and using Iteration 2 with an auc of 0.95.
# len / 2^9 => Using 100 PSMs:
#
# Training in iteration 1 with split 1/3 starts!
# Length of positive trainingset: 5, length of negative training set: 26
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Optimal parameters are C=1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 1 with split 2/3 starts!
# Length of positive trainingset: 10, length of negative training set: 26
# Optimal parameters are C=0.1 and class_weight={0: 30, 1: 10}.
#
# Training in iteration 1 with split 3/3 starts!
# Length of positive trainingset: 11, length of negative training set: 26
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Optimal parameters are C=1 and class_weight={0: 10, 1: 10}.
#
# Using identifications at 1% q-value with rank 1 as metric.
# Iteration 1/10 done! It yielded identifications of 16.
#
# Training in iteration 2 with split 1/3 starts!
# Length of positive trainingset: 10, length of negative training set: 26
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 2 with split 2/3 starts!
# Length of positive trainingset: 6, length of negative training set: 26
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 2 with split 3/3 starts!
# Length of positive trainingset: 9, length of negative training set: 26
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Iteration 2/10 done! It yielded identifications of 11.
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Re-ranking complete. Cutting off low ranks.
#
# Training in iteration 3 with split 1/3 starts!
# Length of positive trainingset: 10, length of negative training set: 26
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 3 with split 2/3 starts!
# Length of positive trainingset: 9, length of negative training set: 26
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Optimal parameters are C=0.1 and class_weight={0: 3, 1: 10}.
#
# Training in iteration 3 with split 3/3 starts!
# Length of positive trainingset: 7, length of negative training set: 26
# Optimal parameters are C=0.1 and class_weight={0: 30, 1: 10}.
#
# Iteration 3/10 done! It yielded identifications of 14.
#
# Training in iteration 4 with split 1/3 starts!
# Length of positive trainingset: 9, length of negative training set: 26
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 4 with split 2/3 starts!
# Length of positive trainingset: 10, length of negative training set: 26
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Training in iteration 4 with split 3/3 starts!
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Length of positive trainingset: 9, length of negative training set: 26
# Optimal parameters are C=0.1 and class_weight={0: 10, 1: 10}.
#
# Iteration 4/10 done! It yielded identifications of 13.
#
# Results are not getting better. Terminating and using Iteration 1 with identifications of 16.
# len / 2^10 => Using 50 PSMs:
#
# Dataset too small. There are not enough positive or negative examples to perform nested cross-validation.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <timed exec> in <module>
#
# ~\Documents\Uni\Bachelorarbeit\Bachelor-Thesis\src\pycolator.py in pseudoROC(df, xMax, onlyFirstRank, onlyVals, qColName, rankColName, title, label, plot)
#      31 def pseudoROC(df, xMax = 0.05, onlyFirstRank = True, onlyVals = False, qColName = 'q-val', rankColName = 'Rank', title = '', label = '', plot = True):
#      32     if (onlyFirstRank):
# ---> 33         temp = pd.DataFrame(df.loc[df.Rank == 1, [qColName, 'Label', rankColName, 'NuXL:isXL']])
#      34         temp = calcQ(temp, qColName, ascending = True)
#      35         qVals = temp.loc[temp[qColName] <= xMax, qColName].values.tolist()
#
# AttributeError: 'NoneType' object has no attribute 'loc'

# %%
rangeOfi = 10
x = [len(dxl)/(math.pow(2,i)) for i in range(rangeOfi)]

ratioAUCs = [p / o if (o!=0) else p + 1 for p,o in zip(aucs,oriAUCs)]
ratioIdents = [p / o for p,o in zip(idents,oriIdents)]
plt.xscale('log')
plt.ylim(0,2.5)
#plt.yscale('log')
print(ratioAUCs)
print(ratioIdents)
plt.plot(x,ratioAUCs)
plt.show()
plt.ylim(0,2.5)
plt.xscale('log')
plt.plot(x,ratioIdents)
# Out:
# [1.6189983267522337, 1.7549332635473631, 1.8053295469115993, 1.8420357537608754, 1.6937008431176008, 2.0342288426095174, 1.6652222041851532, 2.2247814081914443, 0.980656013456686, 1.0]
# [1.7577679137603044, 1.7780596068484464, 1.8491761723700888, 1.9518987341772152, 1.792929292929293, 2.01010101010101, 1.94, 1.56, 2.076923076923077, 2.2857142857142856]

# %%
oriAUCs
# Out:
# [181.32015414316143,
#  86.8725338896442,
#  43.68192266633846,
#  22.616052812258456,
#  11.167249086475055,
#  5.36195071338696,
#  2.6461283537554703,
#  0.8548387096774186,
#  0.931818181818181,
#  0.0,
#  0.0,
#  0.0,
#  0.0]

# %%
aucs
# Out:
# [293.5570261642354,
#  152.4554994115822,
#  78.86026565544833,
#  41.65957788912427,
#  18.913979193067057,
#  10.907434793822434,
#  4.406391689797515,
#  1.9018292682926845,
#  0.9137931034482747,
#  0.0]

# %%
# AUCS of percolator
plt.xscale('log')
plt.yscale('log')

plt.plot([len(dxl)/(math.pow(2,i)) for i in range(rangeOfi)], aucs)
plt.title('AUC of XLs in dSlow using optimal ranking over number of PSMs in dataset')
plt.savefig('../results/ratioTests/optimalRanking_idents.png')

# %%
# Idents of percolator
plt.xscale('log')
plt.yscale('log')

plt.plot([len(dxl)/(math.pow(2,i)) for i in range(rangeOfi)], idents)
plt.title('Idents (1% FDR) of dSlow[XL] over num of PSMs in dataset')
plt.savefig('../results/ratioTests/optimalRanking_idents.png')

# %%
# ratio of idents in df of percolator
plt.xscale('log')
plt.plot([len(dxl)/(math.pow(2,i)) for i in range(rangeOfi)],[idents[i]/(len(dxl)/(math.pow(2,i))) for i in range(rangeOfi)])

# %%
# ratio of idents in df of NuXL
plt.xscale('log')
plt.plot([len(dSlow)/(math.pow(2,i)) for i in range(rangeOfi)],[oriIdents[i]/(len(dSlow)/(math.pow(2,i))) for i in range(rangeOfi)])
